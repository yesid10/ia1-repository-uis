# %% [markdown]
# <img src="https://i.ibb.co/x65XC1B/banner-2.png" align="center"/>

# %%
#@title 1. MONTAR EL DRIVE { display-mode: "form" }
import os
from google.colab import drive
drive.mount('/content/drive')
os.chdir('/content/drive/My Drive/Cardiotocography_classification')
print(os.getcwd())
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/Cardiotocography_classification

# %%
#@title 2. CARGAR LIBRERIAS { display-mode: "form" }
import scipy.stats as stats
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split
from sklearn.metrics import *
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from imblearn.over_sampling import SMOTE
from matplotlib.pyplot import figure
import tensorflow as tf
from tensorflow import keras
# !pip install imblearn
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.neighbors.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)
# Requirement already satisfied: imblearn in /usr/local/lib/python3.6/dist-packages (0.0)
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.6/dist-packages (from imblearn) (0.4.3)
# Requirement already satisfied: scipy>=0.13.3 in /usr/local/lib/python3.6/dist-packages (from imbalanced-learn->imblearn) (1.4.1)
# Requirement already satisfied: scikit-learn>=0.20 in /usr/local/lib/python3.6/dist-packages (from imbalanced-learn->imblearn) (0.22.2.post1)
# Requirement already satisfied: numpy>=1.8.2 in /usr/local/lib/python3.6/dist-packages (from imbalanced-learn->imblearn) (1.18.5)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn>=0.20->imbalanced-learn->imblearn) (0.16.0)

# %% [markdown]
# El proyecto está hecho en base a un dataset denominado "Cardiotocography Data Set".
#
# *   El dataset se encuentra en el siguiente enlace: https://archive.ics.uci.edu/ml/datasets/Cardiotocography

# %%
#Importamos el dataframe
d =pd.read_excel("data/CTG.xls","Datos")
print(d.shape)
d.head()
# Out:
# (2126, 40)
#        FileName       Date      SegFile    b     e  ...  LD  FS  SUSP  CLASS  NSP
# 0  Variab10.txt 1996-12-01  CTG0001.txt  240   357  ...   0   1     0      9    2
# 1    Fmcs_1.txt 1996-05-03  CTG0002.txt    5   632  ...   0   0     0      6    1
# 2    Fmcs_1.txt 1996-05-03  CTG0003.txt  177   779  ...   0   0     0      6    1
# 3    Fmcs_1.txt 1996-05-03  CTG0004.txt  411  1192  ...   0   0     0      6    1
# 4    Fmcs_1.txt 1996-05-03  CTG0005.txt  533  1147  ...   0   0     0      2    1
#
# [5 rows x 40 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Preprocesamiento

# %% [markdown]
# Ante todo, se deben eliminar las columnas innecesarias del dataset, ya que pueden llegar a aportar de forma negativa los resultados.

# %%
df = d.drop(['FileName', 'Date', 'SegFile', 'b', 'e', 'A', 'B', 'C','D','E','AD','DE','LD','FS','SUSP','CLASS', 'LBE', 'DR', 'DS', 'DP', 'Mode', 'Median'], axis=1)
df.head()
# Out:
#     LB  AC  FM  UC  ASTV  MSTV  ...  Nmax  Nzeros  Mean  Variance  Tendency  NSP
# 0  120   0   0   0    73   0.5  ...     2       0   137        73         1    2
# 1  132   4   0   4    17   2.1  ...     6       1   136        12         0    1
# 2  133   2   0   5    16   2.1  ...     5       1   135        13         0    1
# 3  134   2   0   6    16   2.4  ...    11       0   134        13         1    1
# 4  132   4   0   5    16   2.4  ...     9       0   136        11         1    1
#
# [5 rows x 18 columns]

# %% [markdown]
# Los label del dataset se encuentran en el rango del 1 al 3, para evitar confusiones y errores, se reasignan los valores con el numero anterior, es decir, ahora los label estarán en el rango de 0 a 2.

# %%
df['NSP'] = df['NSP'].replace([1],0)
df['NSP'] = df['NSP'].replace([2],1)
df['NSP'] = df['NSP'].replace([3],2)

# %% [markdown]
# <table style="margin:auto;">
# <tbody>
#   <tr>
#     <th> Estado del paciente</th>
#     <th> Label </th>
#   </tr>
#   <tr>
#     <td> Normal </td>
#     <td> 0 </td>
#   </tr>
#   <tr>
#     <td> Sospechoso </td>
#     <td> 1 </td>
#   </tr>
#   <tr>
#     <td> Patológico </td>
#     <td> 2 </td>
#   </tr>

# %%
#@title 1. Correlación de los datos { display-mode: "form" }
import seaborn as sns

f, ax = plt.subplots(figsize=(15, 15))
corr = df.corr()
sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap=sns.diverging_palette(220, 10, as_cmap=True),
            square=True, ax=ax)

# %%
#Definimos x e y
x=df.values[:,:-1]
y=df.values[:,-1]
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.2)

# %%
#Función de entrenamiento y test para un modelo

def run_model(est, x_train, x_test, y_train, y_test):
  est.fit(x_train,y_train)
  y_predict = est.predict(x_test)
  score=cross_val_score(est,x_test,y_test,cv=KFold(10,shuffle=True),scoring=make_scorer(accuracy_score))
  return est, y_predict, np.mean(score)

#Matriz de confusión

def matriz_confusion(y_test, y_predict):
    conf_matrix = confusion_matrix(y_test, y_predict)
    plt.figure(figsize=(10, 8))
    sns.heatmap(conf_matrix, xticklabels=target, yticklabels=target, annot=True, fmt="d");
    plt.title("Matriz de confusión")
    plt.ylabel('Clase verdadera')
    plt.xlabel('Clase predicha')
    plt.show()
    print (classification_report(y_test, y_predict))
    return None

# %% [markdown]
# El balance de clases es un factor fundamental a la hora de iniciar un proyecto, no obstante, en áreas como la medicina, es muy común encontrar un gran desbalance en los datasets, debido a que la gran mayoría de exámenes realizados a personas dan un resultado negativo, es decir, el paciente no posee la patología.
#
# Esto, se puede observar en el siguiente diagrama de barras, el cual corresponde al balance de clases del dataset utilizado.

# %%
#@title 2. Balance de clases { display-mode: "form" }

target= ['Normal', 'Sospechoso', 'Patologógico']
lista = []
for i in range (0,3):
  values = np.sum(y_train==i)
  lista.append(values)
figure(figsize=(10,8))
plt.bar(target, lista)
plt.title("Numero de datos por clase")
plt.xlabel("Clase")
plt.ylabel("Numero de observaciones");

# %% [markdown]
# Como se puede obsevar, existe un desbalance de clases significativo, lo cual representa un problema, no obstante, es pertinente realizar una prueba con un regresor para poder analizar los percances que pueden surgir.

# %% [markdown]
# ### **Clasificación con árbol de decisión**

# %%
estDT=DecisionTreeClassifier()
estDT, yDT_predict, scoreDT = run_model(estDT,x_train,x_test,y_train,y_test)
print(scoreDT)
matriz_confusion(y_test, yDT_predict)
# Out:
# 0.9015503875968992
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.94      0.95       340
#          1.0       0.72      0.77      0.74        62
#          2.0       0.88      0.88      0.88        24
#
#     accuracy                           0.92       426
#    macro avg       0.85      0.86      0.86       426
# weighted avg       0.92      0.92      0.92       426

# %% [markdown]
# Los resultados del score son muy buenos, teniendo un 87.5% de efectividad, no obstante, esta métrica de calificación no es la más óptima para evaluar un modelo en el campo de la medicina, debido a que, el interés del proyecto en general es poder detectar cuando un paciente posee o puede poseer una patología. Teniendo en cuenta el desbalance de clases, es correcto afirmar que la mayoría de predicciones que realizó el modelo corresponde a casos donde el paciente no posee la enfermedad, esto, se puede comprobar en la columna "Support", en donde 343 de los 426 casos son resultados "Normales".
#
# Para poder evaluar correctamente el clasificador, se pueden evaluar otras métricas más sensibles, como lo son:
#
#
# *   Precision
# *   Recall
# *   f1-score
#
# En el caso anteriormente mostrado, se puede apreciar que la precisión en los casos de "Sospechoso" y "Patológico", es menor en relación a los casos "Normales". Para poder obtener un modelo más confiable y preciso, es necesario tener un balance de clases.

# %% [markdown]
# ### Oversampling

# %% [markdown]
# Para poder realizar un balance de clases, se tienen dos opciones, eliminar filas de la clase dominante, o crear muestras artificiales de las clases que representan una minoría. En este proyecto, es más acertado aplicar la última opción mencionada, debido a que si se eliminan filas de la clase dominante, se obtendrían pocas muestras en general, lo cual representa una desventaja en el modelo final, ya que se corre el riesgo de no obtener una generalización del problema.

# %% [markdown]
# Para esto, se utilizará la Técnica de sobremuestreo de minorías sintéticas , o SMOTE.

# %%
smote=SMOTE()
x_res, y_res = smote.fit_sample(x,y)
x_train_res, x_test_res, y_train_res, y_test_res = train_test_split(x_res,y_res,test_size=0.2)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)

# %%
#@title 1. Balance de clases con oversampling { display-mode: "form" }
lista = []
for i in range (0,3):
  values = np.sum(y_train_res==i)
  lista.append(values)
figure(figsize=(10,8))
plt.bar(target, lista)
plt.title("Numero de datos por clase")
plt.xlabel("Clase")
plt.ylabel("Numero de observaciones");

# %% [markdown]
# Luego del sobremuestreo, es evidente el cambio en el balance de clases, por lo tanto, habrá un número de predicciones más equitativo para cada clase.

# %%
estDTBR = DecisionTreeClassifier()
estDTBR, yDTBR_predict, scoreDTBR = run_model(estDTBR,x_train_res,x_test_res,y_train_res,y_test_res)
print(scoreDTBR)
matriz_confusion(y_test_res, yDTBR_predict)
# Out:
# 0.9164343434343435
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.94      0.94       324
#          1.0       0.95      0.96      0.96       329
#          2.0       0.99      0.97      0.98       340
#
#     accuracy                           0.96       993
#    macro avg       0.96      0.96      0.96       993
# weighted avg       0.96      0.96      0.96       993

# %%
#@title 5. Puntaje del modelo según el KFold { display-mode: "form" }
means, stds = [], []
est = DecisionTreeClassifier()
est.fit(x_train_res, y_train_res)
nfolds_range = range(4,17)
for nfolds in nfolds_range:
    #print (nfolds,)
    s = cross_val_score(est, x_test_res, y_test_res, cv=KFold(nfolds, shuffle=True), scoring=make_scorer(accuracy_score))
    means.append(np.mean(s))
    stds.append(np.std(s))

means = np.r_[means]
stds  = np.r_[stds]
plt.plot(nfolds_range, means, label="mean", color="black")
plt.fill_between(nfolds_range, means-stds, means+stds, color="blue", alpha=.5, label="std")
plt.xlabel("n folds")
plt.ylabel("performance")
plt.legend()

# %% [markdown]
# # Pruebas de clasificación

# %% [markdown]
# ###Prueba con Support Vector Machine

# %%
estSV = SVC()
estSV, ySV_predict, scoreSV = run_model(estSV,x_train_res,x_test_res,y_train_res,y_test_res)
print(scoreSV)
matriz_confusion(y_test_res, ySV_predict)
# Out:
# 0.8177777777777777
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.85      0.86       324
#          1.0       0.77      0.87      0.82       329
#          2.0       0.92      0.83      0.87       340
#
#     accuracy                           0.85       993
#    macro avg       0.85      0.85      0.85       993
# weighted avg       0.85      0.85      0.85       993

# %% [markdown]
# ###Prueba con Random Forest

# %%
estRF = RandomForestClassifier()
estRF, yRF_predict, scoreRF = run_model(estRF,x_train_res,x_test_res,y_train_res,y_test_res)
print(scoreRF)
matriz_confusion(y_test_res, yRF_predict)
# Out:
# 0.9496666666666667
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.97      0.97       324
#          1.0       0.98      0.98      0.98       329
#          2.0       0.99      1.00      1.00       340
#
#     accuracy                           0.98       993
#    macro avg       0.98      0.98      0.98       993
# weighted avg       0.98      0.98      0.98       993

# %% [markdown]
# ###Red Neuronal

# %%
#@title 6. Reiniciar el modelo { display-mode: "form" }
keras.backend.clear_session()

# %%
model = keras.models.Sequential([
    keras.layers.Flatten(input_shape= (x_train_res[0].shape)),
    keras.layers.Dense(512, activation=tf.nn.relu),
    keras.layers.Dense(128, activation=tf.nn.relu),
    keras.layers.Dense(3, activation=tf.nn.softmax)
])

# %%
model.compile(optimizer= tf.optimizers.Adam(), 
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(x_train_res, y_train_res, epochs=200)
# Out:
# Epoch 1/200
# 125/125 [==============================] - 0s 2ms/step - loss: 1.4701 - accuracy: 0.7223
# Epoch 2/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.5153 - accuracy: 0.8142
# Epoch 3/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.4549 - accuracy: 0.8293
# Epoch 4/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.4747 - accuracy: 0.8197
# Epoch 5/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3808 - accuracy: 0.8469
# Epoch 6/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3893 - accuracy: 0.8520
# Epoch 7/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.4377 - accuracy: 0.8439
# Epoch 8/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3288 - accuracy: 0.8716
# Epoch 9/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3536 - accuracy: 0.8620
# Epoch 10/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3623 - accuracy: 0.8666
# Epoch 11/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3234 - accuracy: 0.8746
# Epoch 12/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3529 - accuracy: 0.8656
# Epoch 13/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.2756 - accuracy: 0.8907
# Epoch 14/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.2764 - accuracy: 0.8905
# Epoch 15/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3182 - accuracy: 0.8789
# Epoch 16/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.2650 - accuracy: 0.8938
# Epoch 17/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.2686 - accuracy: 0.8973
# Epoch 18/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.2500 - accuracy: 0.8963
# Epoch 19/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.2436 - accuracy: 0.9008
# Epoch 20/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.2311 - accuracy: 0.9076
# Epoch 21/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.2340 - accuracy: 0.9051
# Epoch 22/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.2121 - accuracy: 0.9129
# Epoch 23/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.2188 - accuracy: 0.9126
# Epoch 24/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.2551 - accuracy: 0.8973
# Epoch 25/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.2353 - accuracy: 0.9053
# Epoch 26/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.2232 - accuracy: 0.9124
# Epoch 27/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.2419 - accuracy: 0.9056
# Epoch 28/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.2223 - accuracy: 0.9154
# Epoch 29/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.2238 - accuracy: 0.9066
# Epoch 30/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.2399 - accuracy: 0.9016
# Epoch 31/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.2207 - accuracy: 0.9124
# Epoch 32/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1964 - accuracy: 0.9194
# Epoch 33/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1980 - accuracy: 0.9217
# Epoch 34/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1868 - accuracy: 0.9242
# Epoch 35/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1959 - accuracy: 0.9204
# Epoch 36/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.2155 - accuracy: 0.9174
# Epoch 37/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1965 - accuracy: 0.9204
# Epoch 38/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1893 - accuracy: 0.9282
# Epoch 39/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1804 - accuracy: 0.9275
# Epoch 40/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1799 - accuracy: 0.9328
# Epoch 41/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1654 - accuracy: 0.9328
# Epoch 42/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1871 - accuracy: 0.9242
# Epoch 43/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1773 - accuracy: 0.9295
# Epoch 44/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1766 - accuracy: 0.9295
# Epoch 45/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1688 - accuracy: 0.9325
# Epoch 46/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1457 - accuracy: 0.9406
# Epoch 47/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1994 - accuracy: 0.9277
# Epoch 48/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1654 - accuracy: 0.9325
# Epoch 49/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1650 - accuracy: 0.9325
# Epoch 50/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1592 - accuracy: 0.9378
# Epoch 51/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1643 - accuracy: 0.9378
# Epoch 52/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1482 - accuracy: 0.9418
# Epoch 53/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1725 - accuracy: 0.9325
# Epoch 54/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1691 - accuracy: 0.9343
# Epoch 55/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1446 - accuracy: 0.9436
# Epoch 56/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1431 - accuracy: 0.9426
# Epoch 57/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1405 - accuracy: 0.9428
# Epoch 58/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1459 - accuracy: 0.9391
# Epoch 59/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1580 - accuracy: 0.9378
# Epoch 60/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1407 - accuracy: 0.9476
# Epoch 61/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1313 - accuracy: 0.9507
# Epoch 62/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1418 - accuracy: 0.9413
# Epoch 63/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1914 - accuracy: 0.9288
# Epoch 64/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1350 - accuracy: 0.9496
# Epoch 65/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1216 - accuracy: 0.9491
# Epoch 66/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1445 - accuracy: 0.9418
# Epoch 67/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1405 - accuracy: 0.9456
# Epoch 68/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1322 - accuracy: 0.9494
# Epoch 69/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1312 - accuracy: 0.9474
# Epoch 70/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1435 - accuracy: 0.9449
# Epoch 71/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1344 - accuracy: 0.9489
# Epoch 72/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1163 - accuracy: 0.9569
# Epoch 73/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1484 - accuracy: 0.9408
# Epoch 74/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1178 - accuracy: 0.9562
# Epoch 75/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1369 - accuracy: 0.9486
# Epoch 76/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1099 - accuracy: 0.9595
# Epoch 77/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1689 - accuracy: 0.9386
# Epoch 78/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1257 - accuracy: 0.9557
# Epoch 79/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1346 - accuracy: 0.9484
# Epoch 80/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1235 - accuracy: 0.9496
# Epoch 81/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1226 - accuracy: 0.9514
# Epoch 82/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1058 - accuracy: 0.9607
# Epoch 83/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1048 - accuracy: 0.9605
# Epoch 84/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1293 - accuracy: 0.9499
# Epoch 85/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1149 - accuracy: 0.9567
# Epoch 86/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1037 - accuracy: 0.9650
# Epoch 87/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1027 - accuracy: 0.9602
# Epoch 88/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1305 - accuracy: 0.9502
# Epoch 89/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1035 - accuracy: 0.9615
# Epoch 90/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1221 - accuracy: 0.9564
# Epoch 91/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1010 - accuracy: 0.9595
# Epoch 92/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1025 - accuracy: 0.9602
# Epoch 93/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1165 - accuracy: 0.9567
# Epoch 94/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1629 - accuracy: 0.9411
# Epoch 95/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1094 - accuracy: 0.9562
# Epoch 96/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0941 - accuracy: 0.9658
# Epoch 97/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1191 - accuracy: 0.9524
# Epoch 98/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1019 - accuracy: 0.9580
# Epoch 99/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1047 - accuracy: 0.9602
# Epoch 100/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1213 - accuracy: 0.9524
# Epoch 101/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0953 - accuracy: 0.9625
# Epoch 102/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1119 - accuracy: 0.9602
# Epoch 103/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1031 - accuracy: 0.9600
# Epoch 104/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0998 - accuracy: 0.9622
# Epoch 105/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1210 - accuracy: 0.9549
# Epoch 106/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1108 - accuracy: 0.9627
# Epoch 107/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1024 - accuracy: 0.9620
# Epoch 108/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0853 - accuracy: 0.9680
# Epoch 109/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1112 - accuracy: 0.9557
# Epoch 110/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0790 - accuracy: 0.9680
# Epoch 111/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0932 - accuracy: 0.9637
# Epoch 112/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0885 - accuracy: 0.9635
# Epoch 113/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0854 - accuracy: 0.9693
# Epoch 114/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0818 - accuracy: 0.9698
# Epoch 115/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0835 - accuracy: 0.9668
# Epoch 116/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0794 - accuracy: 0.9713
# Epoch 117/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0857 - accuracy: 0.9663
# Epoch 118/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0894 - accuracy: 0.9653
# Epoch 119/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0730 - accuracy: 0.9736
# Epoch 120/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0838 - accuracy: 0.9673
# Epoch 121/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0863 - accuracy: 0.9660
# Epoch 122/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1217 - accuracy: 0.9577
# Epoch 123/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0736 - accuracy: 0.9716
# Epoch 124/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0700 - accuracy: 0.9741
# Epoch 125/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0912 - accuracy: 0.9648
# Epoch 126/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1159 - accuracy: 0.9564
# Epoch 127/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1162 - accuracy: 0.9559
# Epoch 128/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1000 - accuracy: 0.9605
# Epoch 129/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0887 - accuracy: 0.9655
# Epoch 130/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0981 - accuracy: 0.9660
# Epoch 131/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1233 - accuracy: 0.9557
# Epoch 132/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1438 - accuracy: 0.9524
# Epoch 133/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0749 - accuracy: 0.9716
# Epoch 134/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0750 - accuracy: 0.9716
# Epoch 135/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0820 - accuracy: 0.9695
# Epoch 136/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1044 - accuracy: 0.9660
# Epoch 137/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0909 - accuracy: 0.9642
# Epoch 138/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0688 - accuracy: 0.9743
# Epoch 139/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0710 - accuracy: 0.9746
# Epoch 140/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0711 - accuracy: 0.9728
# Epoch 141/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0807 - accuracy: 0.9678
# Epoch 142/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0866 - accuracy: 0.9673
# Epoch 143/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0825 - accuracy: 0.9700
# Epoch 144/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0848 - accuracy: 0.9673
# Epoch 145/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0641 - accuracy: 0.9766
# Epoch 146/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0758 - accuracy: 0.9683
# Epoch 147/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0815 - accuracy: 0.9685
# Epoch 148/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0739 - accuracy: 0.9731
# Epoch 149/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0698 - accuracy: 0.9746
# Epoch 150/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0695 - accuracy: 0.9743
# Epoch 151/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0728 - accuracy: 0.9698
# Epoch 152/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0710 - accuracy: 0.9728
# Epoch 153/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0782 - accuracy: 0.9688
# Epoch 154/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0696 - accuracy: 0.9726
# Epoch 155/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0904 - accuracy: 0.9675
# Epoch 156/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0649 - accuracy: 0.9733
# Epoch 157/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0632 - accuracy: 0.9773
# Epoch 158/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0591 - accuracy: 0.9763
# Epoch 159/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0803 - accuracy: 0.9710
# Epoch 160/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0610 - accuracy: 0.9758
# Epoch 161/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0728 - accuracy: 0.9738
# Epoch 162/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0557 - accuracy: 0.9773
# Epoch 163/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0537 - accuracy: 0.9796
# Epoch 164/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0895 - accuracy: 0.9660
# Epoch 165/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.1003 - accuracy: 0.9665
# Epoch 166/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0656 - accuracy: 0.9768
# Epoch 167/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0675 - accuracy: 0.9766
# Epoch 168/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0933 - accuracy: 0.9642
# Epoch 169/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0781 - accuracy: 0.9731
# Epoch 170/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0539 - accuracy: 0.9806
# Epoch 171/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0527 - accuracy: 0.9786
# Epoch 172/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0740 - accuracy: 0.9705
# Epoch 173/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0663 - accuracy: 0.9733
# Epoch 174/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0538 - accuracy: 0.9781
# Epoch 175/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0585 - accuracy: 0.9771
# Epoch 176/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0550 - accuracy: 0.9791
# Epoch 177/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0692 - accuracy: 0.9751
# Epoch 178/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0668 - accuracy: 0.9751
# Epoch 179/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0692 - accuracy: 0.9756
# Epoch 180/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0641 - accuracy: 0.9776
# Epoch 181/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0504 - accuracy: 0.9794
# Epoch 182/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0508 - accuracy: 0.9789
# Epoch 183/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0814 - accuracy: 0.9683
# Epoch 184/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0788 - accuracy: 0.9688
# Epoch 185/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0609 - accuracy: 0.9773
# Epoch 186/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0778 - accuracy: 0.9710
# Epoch 187/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0453 - accuracy: 0.9821
# Epoch 188/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0411 - accuracy: 0.9844
# Epoch 189/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0556 - accuracy: 0.9781
# Epoch 190/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0681 - accuracy: 0.9746
# Epoch 191/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0573 - accuracy: 0.9766
# Epoch 192/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0735 - accuracy: 0.9693
# Epoch 193/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0576 - accuracy: 0.9776
# Epoch 194/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0725 - accuracy: 0.9726
# Epoch 195/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0642 - accuracy: 0.9763
# Epoch 196/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0697 - accuracy: 0.9751
# Epoch 197/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0573 - accuracy: 0.9776
# Epoch 198/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0533 - accuracy: 0.9814
# Epoch 199/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0433 - accuracy: 0.9839
# Epoch 200/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.0667 - accuracy: 0.9733

# %%
test_loss, test_acc = model.evaluate(x_test_res, y_test_res)
y_prob = model.predict(x_test_res) 
y_predict_res = y_prob.argmax(axis=-1)
print(test_acc)
matriz_confusion(y_test_res, y_predict_res)
# Out:
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0776 - accuracy: 0.9738
# 0.9738166928291321
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.95      0.97       324
#          1.0       0.95      0.98      0.96       329
#          2.0       0.99      0.99      0.99       340
#
#     accuracy                           0.97       993
#    macro avg       0.97      0.97      0.97       993
# weighted avg       0.97      0.97      0.97       993

# %% [markdown]
# # ¿Es necesario aplicar PCA?

# %%
means, stds = [], []
pcac_range = range(5,15)
est = RandomForestClassifier()
for pcac in pcac_range:
    x_pca = PCA(n_components=pcac).fit_transform(x_res)
    x_train_pca,x_test_pca,y_train_pca,y_test_pca= train_test_split(x_pca,y_res,test_size=0.2,shuffle=True)
    est.fit(x_train_pca, y_train_pca)
    y_predict_pca= est.predict(x_test_pca)
    matriz_confusion(y_test_pca, y_predict_pca)
    s = cross_val_score(est, x_test_pca, y_test_pca, cv=KFold(10, shuffle=True), scoring=make_scorer(accuracy_score))
    print("Score:", np.mean(s))
    means.append(np.mean(s))
    stds.append(np.std(s))

means = np.r_[means]
stds  = np.r_[stds]
plt.plot(pcac_range, means, label="mean", color="black")
plt.fill_between(pcac_range, means-stds, means+stds, color="blue", alpha=.5, label="std")
plt.xlabel("n_components")
plt.ylabel("performance")
plt.legend()
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.88      0.91       340
#          1.0       0.85      0.96      0.90       321
#          2.0       0.98      0.93      0.95       332
#
#     accuracy                           0.92       993
#    macro avg       0.93      0.92      0.92       993
# weighted avg       0.93      0.92      0.92       993
#
# Score: 0.8882525252525253
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.93      0.95       335
#          1.0       0.93      0.98      0.96       330
#          2.0       0.98      0.99      0.99       328
#
#     accuracy                           0.96       993
#    macro avg       0.96      0.96      0.96       993
# weighted avg       0.96      0.96      0.96       993
#
# Score: 0.8952828282828283
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.93      0.95       340
#          1.0       0.92      0.96      0.94       309
#          2.0       0.99      0.99      0.99       344
#
#     accuracy                           0.96       993
#    macro avg       0.96      0.96      0.96       993
# weighted avg       0.96      0.96      0.96       993
#
# Score: 0.9053333333333334
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.93      0.95       335
#          1.0       0.93      0.96      0.94       322
#          2.0       0.99      0.99      0.99       336
#
#     accuracy                           0.96       993
#    macro avg       0.96      0.96      0.96       993
# weighted avg       0.96      0.96      0.96       993
#
# Score: 0.9113838383838383
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.94      0.96       356
#          1.0       0.94      0.98      0.96       326
#          2.0       0.98      0.99      0.99       311
#
#     accuracy                           0.97       993
#    macro avg       0.97      0.97      0.97       993
# weighted avg       0.97      0.97      0.97       993
#
# Score: 0.9124242424242425
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.96      0.97       327
#          1.0       0.94      0.98      0.96       332
#          2.0       0.99      0.98      0.99       334
#
#     accuracy                           0.97       993
#    macro avg       0.97      0.97      0.97       993
# weighted avg       0.97      0.97      0.97       993
#
# Score: 0.9264747474747475
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.96      0.97       330
#          1.0       0.95      0.98      0.97       332
#          2.0       0.99      0.99      0.99       331
#
#     accuracy                           0.98       993
#    macro avg       0.98      0.98      0.98       993
# weighted avg       0.98      0.98      0.98       993
#
# Score: 0.9315050505050506
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.94      0.96       360
#          1.0       0.93      0.97      0.95       320
#          2.0       0.98      1.00      0.99       313
#
#     accuracy                           0.97       993
#    macro avg       0.97      0.97      0.97       993
# weighted avg       0.97      0.97      0.97       993
#
# Score: 0.9234646464646465
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.93      0.95       323
#          1.0       0.93      0.98      0.95       332
#          2.0       0.99      0.99      0.99       338
#
#     accuracy                           0.96       993
#    macro avg       0.97      0.96      0.96       993
# weighted avg       0.97      0.96      0.96       993
#
# Score: 0.9224646464646465
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.94      0.95       337
#          1.0       0.94      0.96      0.95       344
#          2.0       0.99      0.98      0.98       312
#
#     accuracy                           0.96       993
#    macro avg       0.96      0.96      0.96       993
# weighted avg       0.96      0.96      0.96       993
#
# Score: 0.9134040404040406
