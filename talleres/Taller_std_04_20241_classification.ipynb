# %% [markdown]
# <img src="https://gitlab.com/bivl2ab/academico/cursos-uis/ai/ai-uis-student/raw/master/imgs/banner_IA.png"  width="1000px" height="200px">
#
# # **Taller 04: Classification**
#
# ## **Outline**
#
# 1. [Ejercicio 1.](#eje1)
# 2. [Ejercicio 2.](#eje2)
# 3. [Ejercicio 3.](#eje3)
# 4. [Ejercicio 4.](#eje4)

# %%
#@title **Execute this cell**
#@markdown Please include your student id
import sys
import inspect

group_id = "IA1-20241-E2" #@param {type:"string"}
assignment_id = group_id +'.taller_classification'
student_id = "2151090" #@param {type:"string"}
"""
Put your student ID here

Example: student_id =  '2152145'
"""
# Out:
# "\nPut your student ID here\n\nExample: student_id =  '2152145'\n"

# %%
 #@title **Execute this cell**
#@markdown **UTILS**
#@markdown Please dont modify any line in this cell

import os
import json
import requests
from collections import namedtuple


Config = namedtuple('Config', ['server_name'])
config = Config(server_name='https://bivlabgrader.azurewebsites.net/api')


def check_solution_and_evaluate(assignment_id: str, student_func_str: str):

    # Set the endpoint and payload.
    payload = {
        'func_str': student_func_str,
        'assignment_id': assignment_id,
        'student_id': student_id
    }
    endpoint_url = config.server_name + '/CheckAndEvaluateSolution'
    # print(endpoint_url)

    # Make request to server with the data coming from the notebook.
    r = requests.post(endpoint_url, params=payload)
    pprint_json_response(r.json())
    return r


def pprint_json_response(response, indent=0):
    """Pretty print the response."""
    for key, value in response.items():
        print('\t' * indent + str(key.capitalize()))

        # If dictionary, do a recurrent call.
        if isinstance(value, dict):
            pprint_json_response(value, indent + 1)
        else:
            # Enumerate elements if list.
            if isinstance(value, list):
                if len(value) == 1:
                    print('\t' * (indent + 1) + str(value[0]))
                else:
                    for i, e in enumerate(value, start=1):
                        print('\t' * (indent + 1) + f'{i}. {e}')
            else:
                print('\t' * (indent + 1) + str(value))

# %%
#@title **Import libraries**

import numpy as np
import pandas as pd
np.random.seed(21)

# %% [markdown]
# ---
# # **Ejercicio 1**  <a name="eje1"></a>
# ---

# %% [markdown]
# El dataset **`'survey lung cancer'`** contiene una serie de caracteristicas que se usarán para establecer si un paciente tiene un diagnóstico (`LUNG_CANCER`) maligno 'YES' o benigno 'NO'.
# - En la columna (`LUNG_CANCER`) convierta los valores categóricos a númericos: convierta `'YES'` en 1, y convierta `'NO'` en 0.
# - En la columna (`GENDER`) convierta los valores categóricos a númericos: convierta `'M'` en 1, y convierta `'F'` en 0.
# - Debe permutar (shuffle) el dataset.
# - El 80% del dataset se utilizará para el entrenamiento y el 20% restante se utilizará para test.<br>
# Utilice el método `train_test_split` con el parámetro: `random_state=21`
# - Utilice como estimador a `Decision Tree Classifier` con parámetros: `criterion="gini"` &nbsp; y &nbsp; `max_depth=35`
# - Retorne el valor de la métrica `accuracy_score`

# %%
#@title **code student**

def taller04_20241_p01(df):
  import numpy as np
  import pandas as pd
  from sklearn.tree import DecisionTreeClassifier
  from sklearn.metrics import accuracy_score
  from sklearn.model_selection import train_test_split
  np.random.seed(21)
  df['None'] = None
  df['None'] = None
  y = None
  X = None
  None, None, None, None = train_test_split(None, None, None=None, random_state=21)
  est = None(None=None, None=None)
  est.None(None, None)
  y_pred = est.None(None)
  return accuracy_score(y_test, y_pred)

# %%
#@title **check your answer**
import pandas as pd

df = pd.read_csv("https://drive.google.com/uc?id=1b4n7GzNZXtdmclI5Wv-zTgF2-FW2nC5D")
taller04_20241_p01(df)

# %%
#@title **send your answer**
student_func_str = inspect.getsource(taller04_20241_p01)
r = check_solution_and_evaluate(assignment_id, student_func_str)

# %% [markdown]
# ---
# # **Ejercicio 2**  <a name="eje2"></a>
# ---

# %% [markdown]
# El dataset **`'emails'`** contiene una serie de columnas que corresponden a la frecuencia con que aparecen palabras usadas en diferentes emails y se busca establecer si la frecuencia de estas palabras están asociadas a ser spam o no.
# - Utilice como características a todas las columnas, **excepto** la última (`Prediction`). Dicha columna será el ground truth.
# - Debe permutar (shuffle) el dataset.
# - El 90% del dataset se utilizará para el entrenamiento y el 10% restante se utilizará para test.<br>
# Utilice el método `train_test_split` con el parámetro: `random_state=21`
# - Utilice `Support Vector Classifier` como estimador con parámetros: `kernel='poly'` y `degree=5`
# - Retorne el valor de la métrica `accuracy_score`

# %%
#@title **code student**
def taller04_20241_p02(df):
  import numpy as np
  import pandas as pd
  from sklearn.svm import SVC
  from sklearn.metrics import accuracy_score
  from sklearn.model_selection import train_test_split
  np.random.seed(21)
  X = None
  y = None
  None, None, None, None = train_test_split(None, None, None=None, random_state=21)
  est = None(None=None, None=None)
  est.None(None,None)
  y_pred = est.None(None)
  return accuracy_score(y_pred, y_test)

# %%
#@title **check your answer**
import pandas as pd

df = pd.read_csv("https://drive.google.com/uc?id=1AVM5I7w4HQ4O-g2f51wudYZiGqbqJYkJ")
taller04_20241_p02(df)

# %%
#@title **send your answer**
student_func_str = inspect.getsource(taller04_20241_p02)
r = check_solution_and_evaluate(assignment_id, student_func_str)

# %% [markdown]
# ---
# # **Ejercicio 3**  <a name="eje3"></a>
# ---

# %% [markdown]
# Utilice el conjunto de datos **`'mushrooms'`**, que contiene características asociadas a diversas especies de hongos.
# - Convierta las variables categóricas a numéricas usando el método `LabelEncoder`.
# - Elimine la columna (`veil-type`).
# - El ground truth será la columna (`class`).
# - Utilice el modelo Gaussian Naive Bayes.
# - Realice una clasificación utilizando un KFold con parámetros: `n_splits=6, shuffle=True, random_state=21` durante el método **Cross Validation**. Use el parámetro `scoring=make_scorer(accuracy_score)`.
# - Devuelva el promedio y la desviación estándar de los valores obtenidos durante **Cross Validation**.
#
# <br>
#
# **Nota:** TODAS las columnas del dataset son categóricas.
# <br>
#
# Método [LabelEncoder](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.LabelEncoder.html)

# %%
#@title **code student**

def taller04_20241_p03(df):
  import numpy as np
  import pandas as pd
  from sklearn.preprocessing import LabelEncoder
  from sklearn.naive_bayes import GaussianNB
  from sklearn.model_selection import KFold, cross_val_score
  from sklearn.metrics import accuracy_score, make_scorer
  le = LabelEncoder()
  mycols = df.None
  for k in range(len(None)):
    df[None[k]] = le.fit_transform(df[None[k]])
  df = None
  X = None
  y = None
  est = None()
  kf = KFold(None=None, None=None, random_state=21)
  cv_results = None(None, None, None, cv=kf, scoring=None(None))
  return np.mean(cv_results), np.std(cv_results)

# %%
#@title **check your answer**
import pandas as pd

df = pd.read_csv("https://drive.google.com/uc?id=1BoD-RQHpoGs1hpoFnJvKDnkJ2ZM8BMFq")
taller04_20241_p03(df)

# %%
#@title **send your answer**
student_func_str = inspect.getsource(taller04_20241_p03)
r = check_solution_and_evaluate(assignment_id, student_func_str)

# %% [markdown]
# ---
# # **Ejercicio 4**  <a name="eje4"></a>
# ---

# %% [markdown]
# El dataset **`'fetal_health'`** contiene una serie de caracteristicas de fetos y se busca establecer una predicción de si el feto es viable o no.
# - Como características se utilizaran todas las columnas, excepto la última (`fetal_health`). Dicha columna será el ground truth.
# - Debe permutar (shuffle) el dataset.
# - El 70% del dataset se utilizará para el entrenamiento y el 30% restante se utilizará para test.<br>
# Utilice el método `train_test_split` con el parámetro: `random_state=21`
# - Como estimador utilice el modelo `Decision Tree Classifier` con parámetros: `criterion="gini", max_depth=20`
# - Devuelva el `accuracy_score`.
# - Realice **ADICIONALMENTE** una clasificación utilizando un KFold con parámetros: `n_splits=4, shuffle=True, random_state=21` durante el método **Cross Validation**. Use el parámetro `scoring=make_scorer(accuracy_score)`.
# - Devuelva el promedio y la desviación estándar de los valores obtenidos durante **Cross Validation**.

# %%
#@title **code student**

def taller04_20241_p04(df):
  import numpy as np
  import pandas as pd
  from sklearn.tree import DecisionTreeClassifier
  from sklearn.model_selection import train_test_split
  from sklearn.model_selection import KFold, cross_val_score
  from sklearn.metrics import accuracy_score, make_scorer
  np.random.seed(21)

  X = None
  y = None
  None, None, None, None = train_test_split(None, None, None=None, random_state=21)
  est = None(None=None, None=None)
  est.None(None, None)
  y_pred = est.None(None)
  ac = accuracy_score(y_test, y_pred)

  kf = KFold(None=None, None=None, random_state=21)
  cv_results = None(None, None, None, cv=kf, scoring=None(None))

  return ac, np.mean(cv_results), np.std(cv_results)

# %%
#@title **check your answer**
import pandas as pd

df = pd.read_csv("https://drive.google.com/uc?id=1jhINq9qki4nJBzOHeV_k0l7DsqzIBe9C")
taller04_20241_p04(df)

# %%
#@title **send your answer**
student_func_str = inspect.getsource(taller04_20241_p04)
r = check_solution_and_evaluate(assignment_id, student_func_str)

# %% [markdown]
# ---
# <img src="https://gitlab.com/bivl2ab/academico/cursos-uis/ai/ai-uis-student/raw/master/imgs/bannerThanks.jpg" alt="Drawing" style="width:700px;"/>
