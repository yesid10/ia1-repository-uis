# %% [markdown]
# <img src="https://gitlab.com/bivl2ab/academico/cursos-uis/ai/ai-uis-student/raw/master/imgs/banner_IA.png"  width="1000px" height="200px">
#
# # **Taller 06: Deep Learning**
#
# ## **Outline**
#
# 1. [Ejercicio 1.](#eje1)
# 2. [Ejercicio 2.](#eje2)
# 3. [Ejercicio 3.](#eje3)

# %%
#@title **Execute this cell**
#@markdown Please include your student id
import sys
import inspect

group_id = "IA1-20242-E2" #@param {type:"string"}
assignment_id = group_id +'.taller_deep_learning'
student_id = "2238327" #@param {type:"string"}
"""
Put your student ID here

Example: student_id =  '2152145'
"""

# %%
 #@title **Execute this cell**
#@markdown **UTILS**
#@markdown Please dont modify any line in this cell

import os
import json
import requests
from collections import namedtuple


Config = namedtuple('Config', ['server_name'])
config = Config(server_name='https://bivlabgrader.azurewebsites.net/api')


def check_solution_and_evaluate(assignment_id: str, student_func_str: str):

    # Set the endpoint and payload.
    payload = {
        'func_str': student_func_str,
        'assignment_id': assignment_id,
        'student_id': student_id
    }
    endpoint_url = config.server_name + '/CheckAndEvaluateSolution'
    # print(endpoint_url)

    # Make request to server with the data coming from the notebook.
    r = requests.post(endpoint_url, params=payload)
    pprint_json_response(r.json())
    return r


def pprint_json_response(response, indent=0):
    """Pretty print the response."""
    for key, value in response.items():
        print('\t' * indent + str(key.capitalize()))

        # If dictionary, do a recurrent call.
        if isinstance(value, dict):
            pprint_json_response(value, indent + 1)
        else:
            # Enumerate elements if list.
            if isinstance(value, list):
                if len(value) == 1:
                    print('\t' * (indent + 1) + str(value[0]))
                else:
                    for i, e in enumerate(value, start=1):
                        print('\t' * (indent + 1) + f'{i}. {e}')
            else:
                print('\t' * (indent + 1) + str(value))

# %%
#@title **Import libraries**

import numpy as np
import pandas as pd
np.random.seed(21)

# %% [markdown]
# ---
# # **Ejercicio 1**  <a name="eje1"></a>
# ---

# %% [markdown]
# El dataset `Emotion_final.csv` contiene frases de texto y sus respectivas etiquetas de emociones, que se dividen en categorías como "happy", "sadness" entre otros. El objetivo de este ejercicio es construir un modelo de clasificación.
#
# Desarrolle una función que:
# - Utilice como ground truth la **última** columna (índice `1000`). Las demás, corresponderán a `X`.
# - Calcule **la cantidad** de valores únicos existentes en la columna del ground truth (`unique_values`).
# - El 80% del dataset se utilizará para el entrenamiento del modelo y el 20% restante se utilizará para testeo.<br>**Utilice** `train_test_split` con parámetros `random_state=21`
#
# - Entrene una red neuronal como modelo secuencial con las siguientes características:
#   - Una capa oculta de 32 neuronas y activación relu.
#   - Una capa oculta de 64 neuronas y activación relu.
#   - Una capa oculta de 128 neuronas y activación relu.
#   - Una capa de salida, con (`unique_values`) neuronas y función de activación softmax.
#   - Compile el modelo con los siguientes parámetros: `optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy']`
#   - Entrene por 10 epochs, con parámetros `verbose=1`
#   - Calcule las predicciones, con parámetros `verbose=1`
# - **Devuelva** la partición de testeo del ground truth,
# - **Devuelva** las predicciones del modelo

# %%
#@title **code student**
def taller06_20242_p01(df):
  import pandas as pd
  import numpy as np
  from sklearn.model_selection import train_test_split
  from sklearn.metrics import accuracy_score
  import tensorflow as tf
  from tensorflow import keras
  tf.random.set_seed(21)
  np.random.seed(21)

  X = None[None:None]
  y = None[None]
  unique_values = len(None.None())

  X_train, X_test, y_train, y_test = None(None, None, None=None, random_state=21)

  model = tf.None.None([
    tf.keras.layers.Flatten(input_shape=(X_train.None[None],)),
    tf.keras.layers.None(None, activation=None),
    tf.keras.layers.None(None, activation=None),
    tf.keras.layers.None(None, activation=None),
    tf.keras.layers.None(unique_values, activation=None)
  ])

  model.None(None='None', None='None', None=['None'])
  model.None(None, None, None=None, None=None)
  y_pred = model.None(None, None=None)

  return y_test, y_pred

# %%
#@title **check your answer**
import pandas as pd

df = pd.read_csv("https://drive.google.com/uc?id=1HvE9uh_JEws4bKllpONzyLwM_FSczpGT", header=None)
r = taller06_20242_p01(df)

# %%
#@title **send your answer**
student_func_str = inspect.getsource(taller06_20242_p01)
r = check_solution_and_evaluate(assignment_id, student_func_str)

# %% [markdown]
# ---
# # **Ejercicio 2**  <a name="eje2"></a>
# ---

# %% [markdown]
# En este ejercicio, se pide desarrollar un modelo de red neuronal secuencial para predecir (calcular la **REGRESIÓN**) del precio de venta de vehículos utilizando el dataset `car data.csv`.
#
# Para ello, desarrolle una función que:
# - **Elimine** la columna (`Car_Name`)
# - Utilice como ground truth la columna (`Selling_Price`). Las demás, corresponderán a `X`.
# - El 80% del dataset se utilizará para el entrenamiento del modelo y el 20% restante se utilizará para testeo.<br>**Utilice** `train_test_split` con parámetros `random_state=21`
#
# - Entrene una red neuronal como modelo secuencial con las siguientes características:
#   - Una capa oculta de 64 neuronas y activación relu.
#   - Una capa oculta de 128 neuronas y activación relu.
#   - Una capa oculta de 256 neuronas y activación relu.
#   - Una capa oculta de 512 neuronas y activación relu.
#   - Una capa de salida con 1 neurona.<br>Recuerde qué sucede con la función de activación en el tipo de problemas de regresión que se manejan en el curso!.
#
#   - Compile el modelo con los siguientes parámetros: `optimizer='adam', loss='mae', metrics=['mae', 'mse']`
#
#   - Entrene por 13 epochs, con parámetros `verbose=1`
#   - Calcule las predicciones, con parámetros `verbose=1`
# - **Devuelva** la partición de testeo del ground truth,
# - **Devuelva** las predicciones del modelo

# %%
#@title **code student**
def taller06_20242_p02(df):
  import pandas as pd
  import numpy as np
  from sklearn.model_selection import train_test_split
  import tensorflow as tf
  from tensorflow import keras
  tf.random.set_seed(21)
  np.random.seed(21)

  df = None.None("None", axis=1)
  X = None.None(None, axis=1)
  y = None["None"]

  X_train, X_test, y_train, y_test = None(None, None, None=None, random_state=21)

  model = tf.keras.None([
    tf.keras.layers.Flatten(input_shape=(X_train.None[None],)),
    tf.keras.layers.None(None, activation=None),
    tf.keras.layers.None(None, activation=None),
    tf.keras.layers.None(None, activation=None),
    tf.keras.layers.None(None, activation=None),
    tf.keras.layers.None(None)
  ])

  model.None(None='None', None='None', None=['None', 'None'])
  model.None(None, None, None=None, None=None)
  y_pred = model.None(None, None=None)

  return y_test, y_pred

# %%
#@title **check your answer**
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv("https://drive.google.com/uc?id=1X2LMRcIpJufXg04W0fRafqKRM9u_9TxZ")
a,b = taller06_20242_p02(df)

plt.scatter(a, np.abs(b), alpha=0.5)
plt.xlabel('Precio de venta real')
plt.ylabel('Precio de venta predicho')
plt.title('Predicción de Precio de Venta de Vehículos')
plt.grid()
plt.show()

# %%
#@title **send your answer**
student_func_str = inspect.getsource(taller06_20242_p02)
r = check_solution_and_evaluate(assignment_id, student_func_str)

# %% [markdown]
# ---
# # **Ejercicio 3**  <a name="eje3"></a>
# ---

# %% [markdown]
# El dataset `seattle-weather.csv` contiene datos meteorológicos de Seattle con información de fechas, precipitaciones, temperaturas, vientos, etc.
# Entrene un modelo de red neuronal secuencial para clasificar la categoría del clima (`weather`).
#
# Para ello, desarrolle una función que:
#
# - **Elimine** la columna (`date`)
#
# - Utilice como ground truth la columna (`weather`). Las demás, corresponderán a `X`.
# - El 90% del dataset se utilizará para el entrenamiento del modelo y el 10% restante se utilizará para testeo.<br>**Utilice** `train_test_split` con parámetros `random_state=21`
#
# - Entrene una red neuronal como modelo secuencial con las siguientes características:
#   - Una capa oculta de 64 neuronas y activación relu.
#   - Una capa oculta de 128 neuronas y activación relu.
#   - Una capa oculta de 256 neuronas y activación relu.
#   - Una capa oculta de 512 neuronas y activación relu.
#   - Una capa de salida, con (`unique_values`) neuronas y función de activación softmax.
#   - Compile el modelo con los siguientes parámetros: `optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy']`
#   - Entrene por 13 epochs, con parámetros `verbose=1`
#   - Calcule las predicciones, con parámetros `verbose=1`
# - **Devuelva** la partición de testeo del ground truth,
# - **Devuelva** las predicciones del modelo

# %%
#@title **code student**
def taller06_20242_p03(df):
  import pandas as pd
  import numpy as np
  from sklearn.model_selection import train_test_split
  import tensorflow as tf
  from tensorflow import keras
  tf.random.set_seed(21)
  np.random.seed(21)

  df = None.None("None", axis=1)
  X = None.None(None, axis=1)
  y = None["None"]
  unique_values = len(None.None())

  X_train, X_test, y_train, y_test = None(None, None, None=None, random_state=21)

  model = tf.keras.None([
    tf.keras.layers.Flatten(input_shape=(X_train.None[None],)),
    tf.keras.layers.None(None, activation=None),
    tf.keras.layers.None(None, activation=None),
    tf.keras.layers.None(None, activation=None),
    tf.keras.layers.None(None, activation=None),
    tf.keras.layers.None(unique_values, activation=None)
  ])

  model.None(None='None', None='None', None=['None'])
  model.None(None, None, None=None, None=None)
  y_pred = model.None(None, None=None)

  return y_test, y_pred

# %%
#@title **check your answer**
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv("https://drive.google.com/uc?id=1BmEVLO_CfurZamHwa3I2WG-RGw1cAM7H")
r = taller06_20242_p03(df)

# %%
#@title **send your answer**
student_func_str = inspect.getsource(taller06_20242_p03)
r = check_solution_and_evaluate(assignment_id, student_func_str)
