# %% [markdown]
# <img src="https://gitlab.com/bivl2ab/academico/cursos-uis/ai/ai-uis-student/raw/master/imgs/banner_IA.png"  width="1000px" height="200px">
#
# # **Taller 01:  Python and Numpy**
#
# ## **Outline**
#
# 1. [Ejercicio 1.](#eje1)
# 2. [Ejercicio 2.](#eje2)
# 3. [Ejercicio 3.](#eje3)

# %%
#@title **Execute this cell**
#@markdown Please include your student id
import sys
import inspect

group_id = "IA1-20241-E2" #@param {type:"string"}
assignment_id = group_id +'.taller_python_numpy'
student_id = "2151090" #@param {type:"string"}
"""
Put your student ID here

Example: student_id =  '2152145'
"""
# Out:
# "\nPut your student ID here\n\nExample: student_id =  '2152145'\n"

# %%
 #@title **Execute this cell**
#@markdown **UTILS**
#@markdown Please dont modify any line in this cell

import os
import json
import requests
from collections import namedtuple


Config = namedtuple('Config', ['server_name'])
config = Config(server_name='https://bivlabgrader.azurewebsites.net/api')


def check_solution_and_evaluate(assignment_id: str, student_func_str: str):

    # Set the endpoint and payload.
    payload = {
        'func_str': student_func_str,
        'assignment_id': assignment_id,
        'student_id': student_id
    }
    endpoint_url = config.server_name + '/CheckAndEvaluateSolution'
    # print(endpoint_url)

    # Make request to server with the data coming from the notebook.
    r = requests.post(endpoint_url, params=payload)
    pprint_json_response(r.json())
    return r


def pprint_json_response(response, indent=0):
    """Pretty print the response."""
    for key, value in response.items():
        print('\t' * indent + str(key.capitalize()))

        # If dictionary, do a recurrent call.
        if isinstance(value, dict):
            pprint_json_response(value, indent + 1)
        else:
            # Enumerate elements if list.
            if isinstance(value, list):
                if len(value) == 1:
                    print('\t' * (indent + 1) + str(value[0]))
                else:
                    for i, e in enumerate(value, start=1):
                        print('\t' * (indent + 1) + f'{i}. {e}')
            else:
                print('\t' * (indent + 1) + str(value))

# %%
#@title **Please delete this if you're going to use it for a student**
def change_notebook_status(assignment_id: str, activate: bool):

    payload = {
        'notebook_id': assignment_id,
        'activate': activate
    }
    endpoint_url = config.server_name + '/ChangeNotebookStatus'

    # Make request to server with the data coming from the notebook.
    r = requests.post(endpoint_url, params=payload)
    pprint_json_response(r.json())
    return r

def change_point_status(assignment_id: str, func_name: str, activate: bool):

    payload = {
        'notebook_id': assignment_id,
        'func_name': func_name,
        'activate': activate
    }
    endpoint_url = config.server_name + '/ChangePointStatus'

    # Make request to server with the data coming from the notebook.
    r = requests.post(endpoint_url, params=payload)
    pprint_json_response(r.json())
    return r

# %% [markdown]
# ### In order to activate the **whole** notebook, it is necessary to put ```activation_mode = True```, nevertheless ```activation_mode = False```

# %%
#@title **Just for professor notebook**
activation_mode = True #@param {type:"boolean"}
r = change_notebook_status(assignment_id=assignment_id, activate=activation_mode)

# %%
#@title **Import libraries**

import numpy as np
import pandas as pd
np.random.seed(21)

# %% [markdown]
# ---
# # **Ejercicio 1**  <a name="eje1"></a>
# ---

# %% [markdown]
# Crear una función que genere un arreglo aleatorio **de números enteros** con la misma dimensión que un arreglo dado $\ a \ $, donde los números aleatorios **enteros** estén acotados dentro del rango definido por el mínimo y el máximo valor del arreglo dado, es decir: $[min(a), max(a)]$.

# %%
#@title **code student**

def taller01_20241_p01(a):
  import numpy as np
  np.random.seed(21)
  dims = None
  mymin = None
  mymax = None
  mynewarray = None(None, None+1, None)
  return mynewarray

# %%
#@title **check your answer**
arreglo = np.arange(21,35)
taller01_20241_p01(arreglo)

# %%
#@title **send your answer**
student_func_str = inspect.getsource(taller01_20241_p01)
r = check_solution_and_evaluate(assignment_id, student_func_str)

# %% [markdown]
# ### **Init professor**
#
# #### In order to activate the **whole** notebook, it is necessary to put ```activation_mode = True```, nevertheless ```activation_mode = False```

# %%
#@title **Just for professor notebook**
activation_mode = True #@param {type:"boolean"}
r = change_point_status(assignment_id=assignment_id, func_name="taller01_20241_p01", activate=activation_mode)

# %%
#@title **code professor**
def taller01_20241_p01(a):
  import numpy as np
  np.random.seed(21)
  dimensiones = a.shape
  minimo = np.min(a)
  maximo = np.max(a)
  # Crear un nuevo arreglo con las mismas dimensiones, lleno de números aleatorios acotados
  nuevo_arreglo = np.random.randint(minimo, maximo+1, dimensiones)
  return nuevo_arreglo

# %%
#@title **Grader**
def grader_taller01_20241_p01(student_func, teacher_func):
    """Archetype function. Make sure to follow the guidelines proposed
    here when creating a function for your students."""

    response = {}
    # 1. Importing allowed libraries
    # IMPORTANT: To avoid import errors, specify the libraries to use.
    # Having too much freedom is not always good.
    import numpy as np
    np.random.seed(21)

    # 3. Inputs declaration:
    # Dummy test data to use as inputs for the functions.
    arreglo = np.arange(21,35)

    try:
        a_t = teacher_func(arreglo)
        a_s = student_func(arreglo)

        # 5. Assign a score and give insights on what could the student
        # do better. This is the most exhaustive part of the grader
        # creation, where the teacher has to check for inconsistencies.
        print(a_t)
        print(a_s)
        result_1 = np.array_equal(a_t, a_s)

        score = 5 if result_1 else 0
        response['score'] = score
        response['message'] = []

        if score == 5.:
            response['message'].append(
                'Well done. You got the highest score.')
        else:
            # Check for inconsistencies.
            response['message'].append('Check if the values are correct.')

    except Exception as e:
        response['error'] = str(e)
        response['score'] = 0.

    return response

grader_taller01_20241_p01(taller01_20241_p01, taller01_20241_p01)

# %% [markdown]
# ### **End professor**

# %% [markdown]
# ---
# # **Ejercicio 2**  <a name="eje2"></a>
# ---

# %% [markdown]
# Crear una función que, dado un arreglo bidimensional de tipo NumPy, reemplace todos los valores NaN por el promedio de los valores no-NaN en cada fila del arreglo.

# %%
#@title **code student**

def taller01_20241_p02(array):
  import numpy as np
  nan_indices = None
  promedios_columnas = np.nanmean(None, axis=0)
  for col in range(None):
    array[None[:, col], col] = None[col]
  return array

# %%
#@title **check your answer**
array_ejemplo = np.array([[1, 2, np.nan],
                          [np.nan, np.nan, 6],
                          [np.nan, 8, 9]])
taller01_20241_p02(array_ejemplo)

# %%
#@title **send your answer**
student_func_str = inspect.getsource(taller01_20241_p02)
r = check_solution_and_evaluate(assignment_id, student_func_str)

# %% [markdown]
# ### **Init professor**
#
# #### In order to activate the **whole** notebook, it is necessary to put ```activation_mode = True```, nevertheless ```activation_mode = False```

# %%
#@title **Just for professor notebook**
activation_mode = True #@param {type:"boolean"}
r = change_point_status(assignment_id=assignment_id, func_name="taller01_20241_p02", activate=activation_mode)

# %%
#@title **code professor**
def taller01_20241_p02(array):
  import numpy as np
  nan_indices = np.isnan(array)
  promedios_columnas = np.nanmean(array, axis=0)
  for col in range(array.shape[1]):
    array[nan_indices[:, col], col] = promedios_columnas[col]
  return array

# %%
#@title **Grader**
def grader_taller01_20241_p02(student_func, teacher_func):
    """Archetype function. Make sure to follow the guidelines proposed
    here when creating a function for your students."""

    response = {}
    # 1. Importing allowed libraries
    # IMPORTANT: To avoid import errors, specify the libraries to use.
    # Having too much freedom is not always good.
    import numpy as np
    #np.random.seed(21)

    # 3. Inputs declaration:
    # Dummy test data to use as inputs for the functions.
    array_ejemplo = np.array([[1, 2, np.nan],
                          [np.nan, np.nan, 6],
                          [np.nan, 8, 9]])

    try:
        a_t = teacher_func(array_ejemplo)
        a_s = student_func(array_ejemplo)

        # 5. Assign a score and give insights on what could the student
        # do better. This is the most exhaustive part of the grader
        # creation, where the teacher has to check for inconsistencies.
        print(a_t)
        print(a_s)
        result_1 = np.array_equal(a_t, a_s)

        score = 5 if result_1 else 0
        response['score'] = score
        response['message'] = []

        if score == 5.:
            response['message'].append(
                'Well done. You got the highest score.')
        else:
            # Check for inconsistencies.
            response['message'].append('Check if the values are correct.')

    except Exception as e:
        response['error'] = str(e)
        response['score'] = 0.

    return response

grader_taller01_20241_p02(taller01_20241_p02, taller01_20241_p02)

# %% [markdown]
# ### **End professor**

# %% [markdown]
# ---
# # **Ejercicio 3**  <a name="eje3"></a>
# ---

# %% [markdown]
# Crear una función que busque un valor específico en una matriz ($A$) y devuelva las posiciones donde se encuentra dicho valor escalar ($b$), en términos de filas (arreglo 1) y columnas (arreglo 2), así:
# - Sea $x_{ij}$ cualquier elemento de la matriz $A \ $, tal que $ \ x_{ij}=b$<br>
# Se debe retornar entonces, **una variable** que contenga los índices de las **filas** y **columnas**, así: `(array([i]),  array([j]))`
#
# - Si el valor no está presente, la función devuelve un arreglo vacío.
#
# Sugerencia: puede usar el método `where`.

# %%
#@title **code student**

def taller01_20241_p03(value, data):
  import numpy as np
  mypos = None
  return mypos

# %%
#@title **check your answer**
datos = np.array([[1, 2, 3],
                  [4, 5, 6],
                  [5, 8, 5]])
valor_a_buscar = 5
posiciones = taller01_20241_p03(valor_a_buscar, datos)
print(posiciones)

# %%
#@title **send your answer**
student_func_str = inspect.getsource(taller01_20241_p02)
r = check_solution_and_evaluate(assignment_id, student_func_str)

# %% [markdown]
# ### **Init professor**
#
# #### In order to activate the **whole** notebook, it is necessary to put ```activation_mode = True```, nevertheless ```activation_mode = False```

# %%
#@title **Just for professor notebook**
activation_mode = True #@param {type:"boolean"}
r = change_point_status(assignment_id=assignment_id, func_name="taller01_20241_p03", activate=activation_mode)

# %%
#@title **code professor**
def taller01_20241_p03(value, data):
  import numpy as np
  mypos = np.where(data == value)
  return mypos

# %%
#@title **Grader**
def grader_taller01_20241_p03(student_func, teacher_func):
    """Archetype function. Make sure to follow the guidelines proposed
    here when creating a function for your students."""

    response = {}
    # 1. Importing allowed libraries
    # IMPORTANT: To avoid import errors, specify the libraries to use.
    # Having too much freedom is not always good.
    import numpy as np
    #np.random.seed(21)

    # 3. Inputs declaration:
    # Dummy test data to use as inputs for the functions.
    datos = np.array([[1, 2, 3],
                  [4, 5, 6],
                  [5, 8, 5]])
    valor_a_buscar = 5

    try:
        a_t = teacher_func(datos, valor_a_buscar)
        a_s = student_func(datos, valor_a_buscar)

        # 5. Assign a score and give insights on what could the student
        # do better. This is the most exhaustive part of the grader
        # creation, where the teacher has to check for inconsistencies.
        print(a_t)
        print(a_s)
        result_1 = np.array_equal(a_t, a_s)

        score = 5 if result_1 else 0
        response['score'] = score
        response['message'] = []

        if score == 5.:
            response['message'].append(
                'Well done. You got the highest score.')
        else:
            # Check for inconsistencies.
            response['message'].append('Check if the values are correct.')

    except Exception as e:
        response['error'] = str(e)
        response['score'] = 0.

    return response

grader_taller01_20241_p03(taller01_20241_p03, taller01_20241_p03)

# %% [markdown]
# ### **End professor**

# %% [markdown]
# ---
# <img src="https://gitlab.com/bivl2ab/academico/cursos-uis/ai/ai-uis-student/raw/master/imgs/bannerThanks.jpg" alt="Drawing" style="width:700px;"/>
