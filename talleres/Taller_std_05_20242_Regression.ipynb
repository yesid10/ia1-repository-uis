# %% [markdown]
# <img src="https://gitlab.com/bivl2ab/academico/cursos-uis/ai/ai-uis-student/raw/master/imgs/banner_IA.png"  width="1000px" height="200px">
#
# # **Taller 05: Regression**
#
# ## **Outline**
#
# 1. [Ejercicio 1.](#eje1)
# 2. [Ejercicio 2.](#eje2)
# 3. [Ejercicio 3.](#eje3)
# 4. [Ejercicio 4.](#eje4)

# %%
#@title **Execute this cell**
#@markdown Please include your student id
import sys
import inspect

group_id = "IA1-20242-E2" #@param {type:"string"}
assignment_id = group_id +'.taller_regression'
student_id = "2151090" #@param {type:"string"}
"""
Put your student ID here

Example: student_id =  '2152145'
"""
# Out:
# "\nPut your student ID here\n\nExample: student_id =  '2152145'\n"

# %%
 #@title **Execute this cell**
#@markdown **UTILS**
#@markdown Please dont modify any line in this cell

import os
import json
import requests
from collections import namedtuple


Config = namedtuple('Config', ['server_name'])
config = Config(server_name='https://bivlabgrader.azurewebsites.net/api')


def check_solution_and_evaluate(assignment_id: str, student_func_str: str):

    # Set the endpoint and payload.
    payload = {
        'func_str': student_func_str,
        'assignment_id': assignment_id,
        'student_id': student_id
    }
    endpoint_url = config.server_name + '/CheckAndEvaluateSolution'
    # print(endpoint_url)

    # Make request to server with the data coming from the notebook.
    r = requests.post(endpoint_url, params=payload)
    pprint_json_response(r.json())
    return r


def pprint_json_response(response, indent=0):
    """Pretty print the response."""
    for key, value in response.items():
        print('\t' * indent + str(key.capitalize()))

        # If dictionary, do a recurrent call.
        if isinstance(value, dict):
            pprint_json_response(value, indent + 1)
        else:
            # Enumerate elements if list.
            if isinstance(value, list):
                if len(value) == 1:
                    print('\t' * (indent + 1) + str(value[0]))
                else:
                    for i, e in enumerate(value, start=1):
                        print('\t' * (indent + 1) + f'{i}. {e}')
            else:
                print('\t' * (indent + 1) + str(value))

# %%
#@title **Import libraries**

import numpy as np
import pandas as pd
np.random.seed(21)

# %% [markdown]
# ---
# # **Ejercicio 1**  <a name="eje1"></a>
# ---

# %% [markdown]
# El dataset `winequality` contiene características químicas como acidez fija, acidez volátil, ácido cítrico, azúcar residual, cloruros, dióxido de azufre libre y total, densidad, pH, sulfatos, y alcohol. Además, permite clasificar vinos según su calidad (`quality`).
#
# - Para obtener `X`, utilice todas las columnas, excepto (`quality`).<br>La columna (`quality`) será el ground truth
# - **Utilice** `train_test_split` con un 10% para test, y parámetros `random_state=21`
# - Emplee como modelo de regresión `RandomForestRegressor` con parámetros `n_estimators=10`
# - **Devuelva** el `mean_squared_error` (`score1`)
# - Seguidamente, mediante Cross-Validation, obtenga los valores (`score2`) del `mean_squared_error` utilizando `cv=3`
# - **Devuelva** el promedio de `score2`
# - **Devuelva** la desviación estándar de `score2`

# %%
#@title **code student**
def taller05_20242_p01(df):
  import numpy as np
  import pandas as pd
  from sklearn.model_selection import train_test_split, cross_val_score
  from sklearn.ensemble import RandomForestRegressor
  from sklearn.metrics import make_scorer, mean_squared_error
  np.random.seed(21)

  X = None
  y = None['None']

  X_train, X_test, y_train, y_test = None(None, None, None=None, random_state=21)
  model = None(None=None)
  model.None(None, None)
  y_pred = model.None(None)
  score1 = None(None, None)
  score2 = None(None, None, None, None=3, scoring=None(None))

  return score1, np.mean(None), np.std(None)

# %%
#@title **check your answer**
import pandas as pd

df = pd.read_csv("https://drive.google.com/uc?id=1AOU7czIwUTfvQ2XltYdc42R0ontoNaRK")
taller05_20242_p01(df)

# %%
#@title **send your answer**
student_func_str = inspect.getsource(taller05_20242_p01)
r = check_solution_and_evaluate(assignment_id, student_func_str)

# %% [markdown]
# ---
# # **Ejercicio 2**  <a name="eje2"></a>
# ---

# %% [markdown]
# El dataset 'credit_data.csv' contiene información sobre factores demográficos y comportamientos financieros que influyen en la capacidad de los individuos para obtener un préstamo. Las características incluyen edad, estado de crédito , y monto del préstamo solicitado, siendo el objetivo final predecir el ingreso (`income`) de los solicitantes.
#
# Se llevará a cabo el siguiente proceso:
#
# - **Elimine** la columna (`clientid`)
# - Utilice la columna (`income`) como ground truth, y las demás columnas se convertirán en `X`
# - **Utilice** `train_test_split` con un 15% para testing y parámetros `random_state=21`
#
# - Entrene un <ins>Decision Tree Regressor</ins> con parámetros `max_depth=130`
# - **Devuelva** el valor del mean absolute error
# - Entrene un <ins>Support Vector Regressor</ins> con parámetros `kernel='poly'`
# - **Devuelva** el valor del mean absolute error

# %%
#@title **code student**
def taller05_20242_p02(df):
  import pandas as pd
  import numpy as np
  from sklearn.tree import DecisionTreeRegressor
  from sklearn.svm import SVR
  from sklearn.model_selection import train_test_split
  from sklearn.metrics import mean_absolute_error
  np.random.seed(21)

  df = None.None("None", axis=1)
  df = None.None()

  X = None[["None", "None", "None"]]
  y = None["None"]

  X_train, X_test, y_train, y_test = None(None, None, None=None, random_state=21)

  est1 = None(None=None)
  est1.None(None, None)
  y_pred1 = est1.None(None)
  score1 = None(None, None)

  est2 = None(None='None')
  est2.None(None, None)
  y_pred2 = est2.None(None)
  score2 = None(None, None)

  return score1, score2

# %%
#@title **check your answer**
import pandas as pd

df = pd.read_csv("https://drive.google.com/uc?id=1jjDiAYMjfCck6oWvzoQmmkucNRztvRew")
taller05_20242_p02(df)

# %%
#@title **send your answer**
student_func_str = inspect.getsource(taller05_20242_p02)
r = check_solution_and_evaluate(assignment_id, student_func_str)

# %% [markdown]
# ---
# # **Ejercicio 3**  <a name="eje3"></a>
# ---

# %% [markdown]
# El dataset `electricity_bill.csv` contiene información sobre el consumo de electricidad y su costo asociado, con características como 'Usage', 'Number of Days', 'Usage per day' y 'Average Temperature'.
#
# Para este ejercicio, el objetivo es predecir el costo (`Charge`) de la factura eléctrica mediante un modelo de regresión. Desarrolle una función que:
#
# - **Elimine** la columna (`Read Date`)
# - **Elimine** la columna (`Read Type`)
# - **Utilice** `train_test_split` con un 15% de los datos para test, y parámetros `random_state=21`
# - Utilice un estimador **Decision Tree Regressor**, con parámetros `max_depth=4, max_leaf_nodes=10, splitter='best'`
# - **Devuelva** los valores del error absoluto promedio
# - **Devuelva** los valores del error cuadrático promedio
# - **Devuelva** los valores de la raíz del error cuadrático promedio

# %%
#@title **code student**
def taller05_20242_p03(df):
  import pandas as pd
  import numpy as np
  from sklearn.tree import DecisionTreeRegressor
  from sklearn.metrics import mean_absolute_error, mean_squared_error
  from sklearn.model_selection import train_test_split
  np.random.seed(21)

  df = None.None("None", axis=1)
  df = None.None("None", axis=1)
  X = None.None("None", axis=1)
  y = None['None']
  X_train, X_test, y_train, y_test = None(None, None, None=None, random_state=21)

  dt_model = None(None=None, None=None, None='None')
  dt_model.None(None, None)
  y_pred = dt_model.None(None)

  mae = None(None, None)
  mse = None(None, None)
  rmse = np.sqrt(None)

  return mae, mse, rmse

# %%
#@title **check your answer**
import pandas as pd

df = pd.read_csv("https://drive.google.com/uc?id=1fjoRsQ1WF-aQXmAo5et3ZE5_z3Nc7FiA")
taller05_20242_p03(df)

# %%
#@title **send your answer**
student_func_str = inspect.getsource(taller05_20242_p03)
r = check_solution_and_evaluate(assignment_id, student_func_str)

# %% [markdown]
# ---
# # **Ejercicio 4**  <a name="eje4"></a>
# ---

# %% [markdown]
# El dataset `weather_prediction_dataset.csv` contiene información meteorológica de Dresden, con características como 'DRESDEN_cloud_cover', 'DRESDEN_wind_speed', 'DRESDEN_wind_gust', 'DRESDEN_humidity', 'DRESDEN_global_radiation', 'DRESDEN_precipitation', 'DRESDEN_sunshine', 'DRESDEN_temp_mean' y 'DRESDEN_temp_min'.<br>
# El objetivo será **predecir** los valores de la columna temperatura máxima (`DRESDEN_temp_max`) utilizando un modelo de regresión.
#
# Para ello, desarrolle una función que:
#
# - **Elimine** la columna (`DATE`)
# - Dividir los datos en conjuntos de entrenamiento y prueba, utilizando un 20% para test.<br>Utilice `train_test_split` con parámetros `random_state=21`.
# - Entrenar un modelo Support Vector Regressor (**SVR**) con parámetros `kernel='linear'`
# - **Devuelva** el error absoluto promedio
# - **Devuelva** la <ins>raíz</ins> del error cuadrático promedio.
# - **Devuelva** la columna (`DRESDEN_global_radiation`) de `X_test` (es decir, (`X_test['DRESDEN_global_radiation']`)) como un `np.array`
# - **Devuelva** el ground truth de testeo (`y_test`) como un `np.array`
# - **Devuelva** las predicciones (`y_pred`) como un `np.array`

# %%
#@title **code student**
def taller05_20242_p04(df):
  import pandas as pd
  import numpy as np
  from sklearn.model_selection import train_test_split
  from sklearn.svm import SVR
  from sklearn.metrics import mean_absolute_error, mean_squared_error
  np.random.seed(21)

  df = None.None("None", axis=1)
  X = None[None[:-1]]
  y = None['None']

  X_train, X_test, y_train, y_test = None(None, None, None=None, random_state=21)

  model = None(None='None')
  model.None(None, None)

  y_pred = model.None(None)

  mae = None(None, None)
  rmse = np.None(None(None, None))

  return mae, rmse, np.array(None['None']), np.array(None), np.array(None)

# %%
#@title **check your answer**
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("https://drive.google.com/uc?id=1_LiAyLFiQQsyGj4eJKnvOSbI0fSPpjXa")
a, b, c, d, e = taller05_20242_p04(df)

print(a, b)
plt.figure(figsize=(10, 6))
plt.scatter(c, d, alpha=0.7, label='DRESDEN_temp_max ($y$)')
plt.scatter(c, e, alpha=0.7, label='predicted ($\hat{y}$)')
plt.xlabel('DRESDEN_global_radiation')
plt.ylabel('temp_max')
plt.legend()
plt.grid()
plt.show()

# %%
#@title **send your answer**
student_func_str = inspect.getsource(taller05_20242_p04)
r = check_solution_and_evaluate(assignment_id, student_func_str)
