# %% [markdown]
# <img src="https://gitlab.com/bivl2ab/academico/cursos-uis/ai/ai-uis-student/raw/master/imgs/banner_IA.png"  width="1000px" height="200px">
#
# # **Taller 05: Regression**
#
# ## **Outline**
#
# 1. [Ejercicio 1.](#eje1)
# 2. [Ejercicio 2.](#eje2)
# 3. [Ejercicio 3.](#eje3)
# 4. [Ejercicio 4.](#eje4)

# %%
#@title **Execute this cell**
#@markdown Please include your student id
import sys
import inspect

group_id = "IA1-20241-E2" #@param {type:"string"}
assignment_id = group_id +'.taller_regression'
student_id = "2151090" #@param {type:"string"}
"""
Put your student ID here

Example: student_id =  '2152145'
"""
# Out:
# "\nPut your student ID here\n\nExample: student_id =  '2152145'\n"

# %%
 #@title **Execute this cell**
#@markdown **UTILS**
#@markdown Please dont modify any line in this cell

import os
import json
import requests
from collections import namedtuple


Config = namedtuple('Config', ['server_name'])
config = Config(server_name='https://bivlabgrader.azurewebsites.net/api')


def check_solution_and_evaluate(assignment_id: str, student_func_str: str):

    # Set the endpoint and payload.
    payload = {
        'func_str': student_func_str,
        'assignment_id': assignment_id,
        'student_id': student_id
    }
    endpoint_url = config.server_name + '/CheckAndEvaluateSolution'
    # print(endpoint_url)

    # Make request to server with the data coming from the notebook.
    r = requests.post(endpoint_url, params=payload)
    pprint_json_response(r.json())
    return r


def pprint_json_response(response, indent=0):
    """Pretty print the response."""
    for key, value in response.items():
        print('\t' * indent + str(key.capitalize()))

        # If dictionary, do a recurrent call.
        if isinstance(value, dict):
            pprint_json_response(value, indent + 1)
        else:
            # Enumerate elements if list.
            if isinstance(value, list):
                if len(value) == 1:
                    print('\t' * (indent + 1) + str(value[0]))
                else:
                    for i, e in enumerate(value, start=1):
                        print('\t' * (indent + 1) + f'{i}. {e}')
            else:
                print('\t' * (indent + 1) + str(value))

# %%
#@title **Import libraries**

import numpy as np
import pandas as pd
np.random.seed(21)

# %% [markdown]
# ---
# # **Ejercicio 1**  <a name="eje1"></a>
# ---

# %% [markdown]
# En este ejercicio se realizará una regresión que tenga como objetivo predecir las edades (`age`) de una población de zarigüeyas usando las siguientes indicaciones:
#
# - Elimine los valores NaN (por favor siga esta indicación).
# - La columna (`age`) será el ground truth.
# - Convierta las columnas categóricas (`Pop`) y (`sex`) a numéricas.
# - Utilice un 70% del dataset para entrenar y un 30% para test. Emplee la función `train_test_split` **desactivando** la opción `shuffle`.
#
# - Debe entrenar un estimador `Decision Tree Regressor` con el parámetro: `random_state=21`.
# - Explore los siguientes valores del parámetro max_depth: $[2,10,50,100,500]$.
# - Devuelva **una lista** `scores` con el valor del **mean squared error (MSE)** para cada uno.
# - Devuelva las etiquetas `y_test`.

# %%
#@title **code student**
def taller05_20241_p01(df):
  import pandas as pd
  import numpy as np
  from sklearn.model_selection import train_test_split
  from sklearn.tree import DecisionTreeRegressor
  from sklearn.metrics import make_scorer, mean_squared_error
  from sklearn.preprocessing import LabelEncoder
  np.random.seed(21)

  df = df.None()
  df.loc[:,'None'] = df['None'].replace({'None':None, 'None':None})
  df.loc[:,'None'] = df['None'].replace({'None':None, 'None':None})
  x= df.None(["None"], axis=1)
  y = df["None"]

  None, None, None, None =  train_test_split(None, None, None=None, shuffle=False)

  scores1 = []
  for md in [None,None,None,None,None]:
    est1 = None(None=None, None=None)
    est1.None(None, None)
    pred = est1.None(None)
    rmse = np.None(None(None,None))
    scores1.append(rmse)

  return scores1, pred

# %%
#@title **check your answer**
import pandas as pd

df = pd.read_csv("https://drive.google.com/uc?id=1XNiA969kPGKE6l6e0mXmBaXLZfU_K7vX")
taller05_20241_p01(df)

# %%
#@title **send your answer**
student_func_str = inspect.getsource(taller05_20241_p01)
r = check_solution_and_evaluate(assignment_id, student_func_str)

# %% [markdown]
# ---
# # **Ejercicio 2**  <a name="eje2"></a>
# ---

# %% [markdown]
# En este ejercicio se realizará una regresión que tenga como objetivo predecir la calidad (`quality`) del vino.
#
# - Elimine los valores NaN (por favor siga esta indicación).
# - La columna (`quality`) será el ground truth.
# - Utilice un 75% del dataset para entrenar y un 25% para test. Emplee la función `train_test_split` con parámetros: `shuffle=True, random_state=21`.
#
# - Debe entrenar un estimador `RandomForestRegressor` con los parametros: `n_estimators=5, max_depth=100, random_state=21`
#
# - Retorne el **mean squared error (MSE)**

# %%
#@title **code student**
def taller05_20241_p02(df):
  import pandas as pd
  import numpy as np
  from sklearn.model_selection import train_test_split
  from sklearn.ensemble import RandomForestRegressor
  from sklearn.metrics import mean_squared_error
  np.random.seed(21)

  df = df.None()
  x = df.None(["None"], axis=1)
  y = df["None"]
  None, None, None, None = train_test_split(None, None, None=None, shuffle=True, None=None)

  regressor = None(None=None, None=None, None=None)
  regressor.None(None, None)
  y_pred = regressor.None(None)
  mse = None(None, None)
  return mse

# %%
#@title **check your answer**
import pandas as pd

df = pd.read_csv("https://drive.google.com/uc?id=1ZYJiyBSMeHFw6qzDFggKexb-izHxeqFH")
taller05_20241_p02(df)

# %%
#@title **send your answer**
student_func_str = inspect.getsource(taller05_20241_p02)
r = check_solution_and_evaluate(assignment_id, student_func_str)

# %% [markdown]
# ---
# # **Ejercicio 3**  <a name="eje3"></a>
# ---

# %% [markdown]
# El conjunto de datos **`'garments_worker_productivity'`** incluye atributos importantes del proceso de confecciones (garments) y la productividad de los empleados, que se han recogido manualmente y también han sido validados por expertos del sector.
# - Elimine los valores NaN (por favor siga esta indicación).
# - La columna (`actual_productivity`) será el ground truth.
# - Limpie el dataset eliminando `"date", "day","quarter","department"`.
# - Use el estimador `Random Forest Regressor` para predecir el (`actual_productivity`).
# - Utilice una estrategia de **Cross Validation**, con `KFold(n_splits=5, shuffle=True, random_state=21)` y calcule el `mean_absolute_error`.
# - **Devuelva** el promedio y la desviación estándar de `scores`.

# %%
#@title **code student**
def taller05_20241_p03(df):
  import pandas as pd
  import numpy as np
  from sklearn.model_selection import cross_val_score
  from sklearn.ensemble import RandomForestRegressor
  from sklearn.metrics import mean_absolute_error
  from sklearn.metrics import make_scorer
  from sklearn.model_selection import KFold
  np.random.seed(21)

  df = df.None()
  X = df.None(["None","None","None","None","None"], axis=1)
  y = df["None"]
  est = None()
  kf = None(None=None, None=None, None=None)
  scores = cross_val_score(None, None, None, cv=None, None=None(mean_absolute_error))
  return np.mean(scores), np.std(scores)

# %%
#@title **check your answer**
import pandas as pd

df = pd.read_csv("https://drive.google.com/uc?id=1Hfvi-xzaBS6LcDqjhAKJsv9Q18rzNR84")
taller05_20241_p03(df)

# %%
#@title **send your answer**
student_func_str = inspect.getsource(taller05_20241_p03)
r = check_solution_and_evaluate(assignment_id, student_func_str)

# %% [markdown]
# ---
# # **Ejercicio 4**  <a name="eje4"></a>
# ---

# %% [markdown]
# Vamos a observar el efecto de reducir la dimensionalidad en un dataset mediante la obtención de diferentes números de componentes principales.
#
# - Elimine los valores NaN (por favor siga esta indicación).
#
# - Utilice las columnas: `"Holiday_Flag", "Temperature", "Fuel_Price", "CPI", "Unemployment"`
#
# - La columna (`Weekly_Sales`) será el ground truth.
#
# - Utilice un 82% del dataset para entrenar y un 18% para test. Emplee la función `train_test_split` con el parámetro `random_state=21`.
#
# - Utilice como regresores:
#   -  SVR con el parámetro `kernel='linear'`
#   -  SVR con el parámetro `kernel='poly'`
#   -  SVR con el parámetro `kernel='rbf'`
#
# - Devuelva **una lista** `scores` con los valores de la métrica **RMSE** obtenidos para cada regresor.

# %%
#@title **code student**
def taller05_20241_p04(df):
  import pandas as pd
  import numpy as np
  from sklearn.model_selection import train_test_split
  from sklearn.svm import SVR
  from sklearn.metrics import mean_squared_error
  np.random.seed(21)

  df = df.None()
  X = df[["None", "None", "None", "None", "None"]]
  y = df["None"]
  None, None, None, None = train_test_split(None, None, None=None, random_state=21)

  scores = []
  kernels = ['None', 'None', 'None']
  for k in kernels:
    est = None(None=None)
    est.None(None, None)
    y_pred = est.None(None)
    scores.append(np.None(None(None, None)))

  return scores

# %%
#@title **check your answer**
import pandas as pd

df = pd.read_csv("https://drive.google.com/uc?id=1g7_-MaxB0hkIOF5tLggiwHSAeM8irux8")
taller05_20241_p04(df)

# %%
#@title **send your answer**
student_func_str = inspect.getsource(taller05_20241_p04)
r = check_solution_and_evaluate(assignment_id, student_func_str)

# %% [markdown]
# ---
# <img src="https://gitlab.com/bivl2ab/academico/cursos-uis/ai/ai-uis-student/raw/master/imgs/bannerThanks.jpg" alt="Drawing" style="width:700px;"/>
