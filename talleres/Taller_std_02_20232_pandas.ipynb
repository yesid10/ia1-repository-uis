# %% [markdown]
# <img src="https://gitlab.com/bivl2ab/academico/cursos-uis/ai/ai-uis-student/raw/master/imgs/banner_IA.png"  width="1000px" height="200px">
#
# # **Taller 02:  Pandas**
#
# ## **Outline**
#
# 1. [Ejercicio 1.](#eje1)
# 2. [Ejercicio 2.](#eje2)
# 2. [Ejercicio 3.](#eje3)
# 2. [Ejercicio 4.](#eje4)
# 2. [Ejercicio 5.](#eje5)

# %%
#@title **Execute this cell**
#@markdown Please include your student id
import sys
import inspect

group_id = "IA1-20232-E1" #@param {type:"string"}
assignment_id = group_id +'.taller_pandas'
student_id = "2151090" #@param {type:"string"}
"""
Put your student ID here

Example: student_id =  '2152145'
"""
# Out:
# "\nPut your student ID here\n\nExample: student_id =  '2152145'\n"

# %%
 #@title **Execute this cell**
#@markdown **UTILS**
#@markdown Please dont modify any line in this cell

import os
import json
import requests
from collections import namedtuple


Config = namedtuple('Config', ['server_name'])
config = Config(server_name='https://bivlabgrader.azurewebsites.net/api')


def check_solution_and_evaluate(assignment_id: str, student_func_str: str):

    # Set the endpoint and payload.
    payload = {
        'func_str': student_func_str,
        'assignment_id': assignment_id,
        'student_id': student_id
    }
    endpoint_url = config.server_name + '/CheckAndEvaluateSolution'
    # print(endpoint_url)

    # Make request to server with the data coming from the notebook.
    r = requests.post(endpoint_url, params=payload)
    pprint_json_response(r.json())
    return r


def pprint_json_response(response, indent=0):
    """Pretty print the response."""
    for key, value in response.items():
        print('\t' * indent + str(key.capitalize()))

        # If dictionary, do a recurrent call.
        if isinstance(value, dict):
            pprint_json_response(value, indent + 1)
        else:
            # Enumerate elements if list.
            if isinstance(value, list):
                if len(value) == 1:
                    print('\t' * (indent + 1) + str(value[0]))
                else:
                    for i, e in enumerate(value, start=1):
                        print('\t' * (indent + 1) + f'{i}. {e}')
            else:
                print('\t' * (indent + 1) + str(value))

# %%
#@title **Import libraries**
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ---
# ## **Comportamiento del producto interno Bruto a nivel Mundial**
#
# En los siguientes puntos vamos a explorar un dataset que describe el  crecimiento de la población mundial (`pop`) por país (`country`), y además describe el comportamiento del producto interno bruto (`gdpPercap`) y la experanza de vida (`lifeExp`).
#
# ---

# %%
#@title **PIB dataset**
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

data = pd.read_csv('https://gitlab.com/bivl2ab/academico/cursos-uis/ai/ai-uis-student/-/raw/master/data/gapminder-FiveYearData.csv?ref_type=heads')
sns.relplot(x="year", y="lifeExp", hue="continent", size="pop",
            sizes=(40, 400), alpha=.5, palette="muted",
            height=6, data=data)
data.head()
# Out:
#        country  year         pop continent  lifeExp   gdpPercap
# 0  Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1  Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2  Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3  Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4  Afghanistan  1972  13079460.0      Asia   36.088  739.981106

# %% [markdown]
# ---
# # **Ejercicio 1**  <a name="eje1"></a>
# ---
# **Calculando nuevas caracteristicas del dataset**
#
# Escriba una función que le agregue una columna al dataframe `data`. La nueva columna debe llamarse `corr_movil` y debe calcular la correlación movil entre las columnas `lifeExp` y `gdpPercap`. La ventana de la correlación movil debe ser calculada con una ventana de tamaño `10`. Los primeros datos serán `NaN` pero deben ser "rellenados" con el valor global de la correlación entre estas dos variables.
#
# La función debe devolver el datadrame `data` con la nueva columna y ademas se deve devolver la matrix de correlación general entre estas dos caracteristicas.

# %%
#@title **Escriba su código aquí!**
#@markdown No modifique las dos últimas lineas
def PIB_new_features():
    import numpy as np
    import pandas as pd


    data_mod = pd.read_csv('https://gitlab.com/bivl2ab/academico/cursos-uis/ai/ai-uis-student/-/raw/master/data/gapminder-FiveYearData.csv?ref_type=heads')

    'your code here'
    data_mod = None
    corr_mat = None


    return data_mod, corr_mat

# %%
#@title **verifique su respuesta**
data_mod, corr_mat = PIB_new_features()
print(corr_mat)
data_mod.head(3)

# %%
#@title **Evalue su respuesta.**
student_func_str = inspect.getsource(PIB_new_features)
r = check_solution_and_evaluate(assignment_id, student_func_str)

# %% [markdown]
# # **Ejercicio 2**  <a name="eje4"></a>
#
# **Agrupamiento.**
# Una de los mecanismos mas sofisticados para entender, analizar y visualizar los datos son los métodos de agrupamiento. Pandas ofrece varios metodos de agrupamiento como es `groupby` y `pivot_table`. Para entender mejor su potencialidad vamos a crear una función que cree y retorne dos nuevos dataframes, con la siguiente descripción:
#
# - Un dataframe que agrupe la información por los continentes y calcule en cada registro la operación media.
# - Un dataframe construido con `pivot_table` que permita observar mas detalladamente la información.  Esta tabla debe indexar los datos por `year`, la columna debe ser `continent` y la función que debe operar es `max`

# %%
#@title **Escriba su código aquí!**
#@markdown No modifique las dos últimas lineas
def PIB_group_by():
    import numpy as np
    import pandas as pd

    data_mod = pd.read_csv('https://gitlab.com/bivl2ab/academico/cursos-uis/ai/ai-uis-student/-/raw/master/data/gapminder-FiveYearData.csv?ref_type=heads')

    "your code here"
    DF_cont = None
    pivot_t = None

    return DF_cont, pivot_t

# %%
#@title **verifique su respuesta**
DF_cont, pivot_t = PIB_group_by()
DF_cont.head(5)

# %%
 #@title **send your answer**
student_func_str = inspect.getsource(PIB_group_by)
r = check_solution_and_evaluate(assignment_id, student_func_str)

# %% [markdown]
# ---
# # **Ejercicio 3**  <a name="eje3"></a>
# ---
# Observe el dataset "../data/titanic/train.csv" y calcule los siguientes ítems:
# 1. Cuántos sobrevivientes ("Survived") son reportados en el dataset.
# 2. ¿Cuál fue la tarifa ("Fare") promedio de los pasajeros que viajaba en clase ("Pclass") 3?.
# 3. De los pasajeros <u>reportados</u>, ¿Cuántas mujeres abordaron?
# 4. ¿Cuántas mujeres sobrevivieron?
#
# Devuelva sus respuestas en cuatro variables.

# %%
def train_titanic():
  import pandas as pd
  import numpy as np
  data = pd.read_csv("https://gitlab.com/bivl2ab/academico/cursos-uis/ai/ai-uis-student/-/raw/master/data/titanic/train.csv?ref_type=heads")

  "your code here"

  p1 = None
  p2 = None
  p3 = None
  p4 = None

  return p1, p2, p3, p4

# %%
#@title **Check your code**
train_titanic()
# Out:
# (342, 13.675550101832993, 314, 233)

# %%
 #@title **send your answer**
student_func_str = inspect.getsource(train_titanic)
r = check_solution_and_evaluate(assignment_id, student_func_str)

# %% [markdown]
# ---
# # **Ejercicio 4**  <a name="eje4"></a>
# ---
#
# Revise el dataset "../data/shopping_data.csv" y obtenga:
# 1. ¿Cuántos hombres son mayores de 21 años?
# 2. ¿Cuántas personas mayores de 30 años ganan más de 40k?
# 3. ¿Cuál es el ingreso promedio de las personas menores de 30 años?
#
# Devuelva sus respuestas en tres variables.

# %%
def shopping_data():
  import pandas as pd
  import numpy as np
  data = pd.read_csv("https://gitlab.com/bivl2ab/academico/cursos-uis/ai/ai-uis-student/-/raw/master/data/shopping_data.csv?ref_type=heads")

  "Your code here"
  res1 = None
  res2 = None
  res3 = None
  return res1,res2,res3

# %%
 #@title **send your answer**
student_func_str = inspect.getsource(shopping_data)
r = check_solution_and_evaluate(assignment_id, student_func_str)

# %% [markdown]
# ---
# # **Ejercicio 5**  <a name="eje5"></a>
# ---
#
# Identifique el dataset "../data/bikes.csv" y calcule:
# 1. El promedio de la temperatura para el año 2011
# 2. La desviación estándar de la humedad para el año 2012
# 3. La máxima humedad después de 2012-03-01
# 4. La velocidad del viento más baja para todo el dataset
# 5. El promedio de los conteos para el año 2011
#
# Devuelva sus respuestas en cinco variables.

# %%
def bikes_dataframe():
  import pandas as pd
  import numpy as np
  data = pd.read_csv("https://gitlab.com/bivl2ab/academico/cursos-uis/ai/ai-uis-student/-/raw/master/data/bikes.csv?ref_type=heads")

  "Your code here"
  res1 = None
  res2 = None
  res3 = None
  res4 = None
  res5 = None
  return res1,res2,res3,res4,res5

# %%
#@title **send your answer**
student_func_str = inspect.getsource(bikes_dataframe)
r = check_solution_and_evaluate(assignment_id, student_func_str)

# %% [markdown]
# ---
# <img src="https://gitlab.com/bivl2ab/academico/cursos-uis/ai/ai-uis-student/raw/master/imgs/bannerThanks.jpg" alt="Drawing" style="width:700px;"/>
