# %% [markdown]
# <img src="https://gitlab.com/bivl2ab/academico/cursos-uis/ai/ai-uis-student/raw/master/imgs/banner_IA.png"  width="1000px" height="200px">
#
# # **Taller 03:  Statistics**
#
# ## **Outline**
#
# 1. [Ejercicio 1.](#eje1)
# 2. [Ejercicio 2.](#eje2)
# 3. [Ejercicio 3.](#eje3)
# 4. [Ejercicio 4.](#eje4)

# %%
#@title **Execute this cell**
#@markdown Please include your student id
import sys
import inspect

group_id = "IA1-20241-E1" #@param {type:"string"}
assignment_id = group_id +'.taller_statistic'
student_id = "2151090" #@param {type:"string"}
"""
Put your student ID here

Example: student_id =  '2152145'
"""
# Out:
# "\nPut your student ID here\n\nExample: student_id =  '2152145'\n"

# %%
 #@title **Execute this cell**
#@markdown **UTILS**
#@markdown Please dont modify any line in this cell

import os
import json
import requests
from collections import namedtuple


Config = namedtuple('Config', ['server_name'])
config = Config(server_name='https://bivlabgrader.azurewebsites.net/api')


def check_solution_and_evaluate(assignment_id: str, student_func_str: str):

    # Set the endpoint and payload.
    payload = {
        'func_str': student_func_str,
        'assignment_id': assignment_id,
        'student_id': student_id
    }
    endpoint_url = config.server_name + '/CheckAndEvaluateSolution'
    # print(endpoint_url)

    # Make request to server with the data coming from the notebook.
    r = requests.post(endpoint_url, params=payload)
    pprint_json_response(r.json())
    return r


def pprint_json_response(response, indent=0):
    """Pretty print the response."""
    for key, value in response.items():
        print('\t' * indent + str(key.capitalize()))

        # If dictionary, do a recurrent call.
        if isinstance(value, dict):
            pprint_json_response(value, indent + 1)
        else:
            # Enumerate elements if list.
            if isinstance(value, list):
                if len(value) == 1:
                    print('\t' * (indent + 1) + str(value[0]))
                else:
                    for i, e in enumerate(value, start=1):
                        print('\t' * (indent + 1) + f'{i}. {e}')
            else:
                print('\t' * (indent + 1) + str(value))

# %%
#@title **Import libraries**

import numpy as np
import pandas as pd
import scipy.stats as stats

# %% [markdown]
# # **US Stores Sales**
# El dataset [`US Stores Sales`](https://www.kaggle.com/datasets/dsfelix/us-stores-sales) contiene información sobre las ventas (en dólares) en tiendas norteamericanas entre los años 2010 y 2011. Este dataset muestra datos como el área de las tiendas, el estado en donde están ubicadas, el tamaño, entre otros.

# %%
import pandas as pd
url = "https://drive.google.com/uc?id=11jogBqci3Spmiy5EoJu82_OMXNOD1Mcg"
df = pd.read_csv(url)

# %%
print(df.shape)
df.head()
# Out:
# (4248, 20)
#    Area Code        State Market   Market Size  Profit  Margin  Sales   COGS  \
# 0        203  Connecticut   East  Small Market   107.0   176.0  292.0  116.0
# 1        203  Connecticut   East  Small Market    75.0   135.0  225.0   90.0
# 2        203  Connecticut   East  Small Market   122.0   195.0  325.0  130.0
# 3        203  Connecticut   East  Small Market   105.0   174.0  289.0  115.0
# 4        203  Connecticut   East  Small Market   104.0   135.0  223.0   90.0
#
#    Total Expenses  Marketing  Inventory  Budget Profit  Budget COGS  \
# 0            69.0       38.0      962.0          110.0        110.0
# 1            60.0       29.0     1148.0           90.0         80.0
# 2            73.0       42.0     1134.0          130.0        110.0
# 3            69.0       37.0     1166.0          110.0        100.0
# 4            56.0       29.0     1148.0           90.0         80.0
#
#    Budget Margin  Budget Sales  ProductId               Date Product Type  \
# ...

# %% [markdown]
# ---
# # **Ejercicio 1**  <a name="eje1"></a>
# ---

# %% [markdown]
# Cree una función que force la creación de dos distribuciones normales de la siguiente manera:
#
# 1. La primera distribución normal debe corresponder a la columna (`Total Expenses`) cuando la columna (`Market Size`) toma el valor "`Major Market`" y usted debe:
#   - **Devolver** el promedio.
#   - **Devolver** la desviación estándar.
#   - **Devolver** la distribución normal.
#
# 2. La segunda distribución normal debe corresponder a la columna (`Total Expenses`) cuando la columna (`Market Size`) toma el valor "`Small Market`" y usted debe:
#   - **Devolver** el promedio.
#   - **Devolver** la desviación estándar.
#   - **Devolver** la distribución normal.

# %%
#@title **code student**
def taller03_20241_p01(df):
  import scipy.stats as stats
  import pandas as pd
  import numpy as np

  media_small_market = None
  desviacion_small_market = None

  media_major_market = None
  desviacion_major_market = None

  sm_dist = None.None(loc=None, scale=None)
  mm_dist = None.None(loc=None, scale=None)

  return media_major_market, desviacion_major_market, mm_dist, media_small_market, desviacion_small_market, sm_dist

# %%
#@title **check your answer**
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

url = "https://drive.google.com/uc?id=11jogBqci3Spmiy5EoJu82_OMXNOD1Mcg"
df = pd.read_csv(url)

avg1, std1, dist1, avg2, std2, dist2 = taller03_20241_p01(df)

x_ref_estim, ref_cont_estim = np.linspace(dist1.ppf(0.01), dist1.ppf(0.99), 100, retstep=True)
plt.plot(x_ref_estim, ref_cont_estim*dist1.pdf(x_ref_estim), label="dist1", color="red")
x_ref_estim, ref_cont_estim = np.linspace(dist2.ppf(0.01), dist2.ppf(0.99), 100, retstep=True)
plt.plot(x_ref_estim, ref_cont_estim*dist2.pdf(x_ref_estim), label="dist2", color="blue")
plt.legend()
plt.show()

# %%
#@title **send your answer**
student_func_str = inspect.getsource(taller03_20241_p01)
r = check_solution_and_evaluate(assignment_id, student_func_str)

# %% [markdown]
# ---
# # **Ejercicio 2**  <a name="eje2"></a>
# ---

# %% [markdown]
# Elabore una función que reciba un dataset y calcule la correlación de los **índices** numéricos de columna que se le pasen, también, como parámetro. Proceda de la siguiente forma:
# - **Devuelva** la correlación de `spearmanr`
# - **Devuelva** el correspondiente p-value de `spearmanr`
# - **Devuelva** el promedio de la primera columna de `idx`
# - **Devuelva** la desviación estándar de la segunda columna de `idx`
#
# Nota: la variable (`idx`) **DEBE** ser una **LISTA** y sus valores serán los índices como elementos.
#
# [Correlación de spearmanr](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.spearmanr.html)

# %%
#@title **code student**
def taller03_20241_p02(df, idx):
  import pandas as pd
  import scipy.stats as stats
  myspearmanr = stats.None(None, None)
  avg = None
  std = None
  return myspearmanr[0], myspearmanr[1], avg, std

# %%
#@title **check your answer**
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

url = "https://drive.google.com/uc?id=11jogBqci3Spmiy5EoJu82_OMXNOD1Mcg"
df = pd.read_csv(url)

taller03_20241_p02(df, [4,7])

# %%
#@title **send your answer**
student_func_str = inspect.getsource(taller03_20241_p02)
r = check_solution_and_evaluate(assignment_id, student_func_str)

# %% [markdown]
# ---
# # **Ejercicio 3**  <a name="eje3"></a>
# ---

# %% [markdown]
# Suponga que al momento de tirar una moneda usted puede obtener como resultado o CARA o SELLO. Sin embargo, si realizamos este mismo experimento 10 veces y se calculan las probabilidades no se obtendran los resultados mencionados. ¿Por qué? ¿Qué sucede si se ejecutan más veces?.
#
# En este ejercicio, usted deberá completar una función, la cual simula el experimento ejecutándolo $N$ veces. Los resultados nos permitiran observar que sucede con las probabilidades cuando incrementamos el número de experimentos.
#
# Complete la función de la siguiente manera:
# - Almacene las probabilidades de obtener CARA o SELLO en dos listas.
# - Simule $N$ experimentos para los valores $\{10, 100, 1000\}$
# - Asuma que la distribución de **Poisson** es la que mejor describe el lanzamiento de una moneda.<br>En cada iteración, genere una (1) muestra de una distribución de poisson con $\ \lambda=0.5$
# - Almacene temporalmente los resultados de cada iteración (cada muestreo individual)
# - Al finalizar cada $N$, obtenga el valor de la probabilidad de obtener CARAS $ \ \ \overline{p} \ \ $ y SELLOS $ \ \ \overline{1-p} \ \ $.
# - **Devuelva** la probabilidad de obtener CARAS
# - **Devuelva** la probabilidad de obtener SELLOS

# %%
#@title **code student**

def taller03_20241_p03():
  import numpy as np
  import scipy.stats as stats
  np.random.seed(21)

  prob_caras = None
  prob_sellos = None
  for N in [None, None, None]:
      resultados = None
      for i in range(N):
          intento = None.None(None).rvs(None)
          resultados.append(intento[0])
      None.append(np.mean(None))
      None.append(1-np.mean(None))

  return prob_caras, prob_sellos

# %%
#@title **check your answer**
taller03_20241_p03()
# Out:
# ([0.3, 0.49, 0.498], [0.7, 0.51, 0.502])

# %%
#@title **send your answer**
student_func_str = inspect.getsource(taller03_20241_p03)
r = check_solution_and_evaluate(assignment_id, student_func_str)

# %% [markdown]
# ---
# # **Ejercicio 4**  <a name="eje4"></a>
# ---

# %% [markdown]
# Teniendo en cuenta el dataset `US Stores Sales` estime una distribución normal **con el CLT** para la columna (`Inventory`) para las filas en donde la columna (`Market Size`) tenga el valor "`Small Market`".
# Para ello, cree una función que haga lo siguiente:
# - Del dataset extraiga los valores de la columna (`Inventory`) cuando la columna (`Market Size`) toma el valor "`Small Market`". Use el nombre de variable `df`
# <br><br>
# - Reemplace los valores nan con el máximo valor de `df`
# - Compute muestreos $N$ con valores $\{2, 10, 40, 100 \} $.
# - **Devuelva** la distribución empírica `estimat_c`
# - **Devuelva** la distribución analítica `analyt_c`

# %%
#@title **code student**
def taller03_20241_p04(df):
  import matplotlib.pyplot as plt
  import numpy as np
  import seaborn as sns
  import pandas as pd
  from scipy import stats
  np.random.seed(21)

  df = None
  d_mean = np.None(None)
  d_std = np.None(None)

  for i, N in enumerate([None, None, None, None]):
    sample_means_m = np.r_[[np.None(np.random.choice(None, size=None)) for _ in range(10000)]]
    estimat_c = stats.None(loc=None, scale=None)
    analyt_c = stats.None(loc=None, scale=None)

  return estimat_c, analyt_c

# %%
#@title **check your answer**
import pandas as pd
url = "https://drive.google.com/uc?id=11jogBqci3Spmiy5EoJu82_OMXNOD1Mcg"
df = pd.read_csv(url)

taller03_20241_p04(df)

# %%
#@title **send your answer**
student_func_str = inspect.getsource(taller03_20241_p04)
r = check_solution_and_evaluate(assignment_id, student_func_str)

# %% [markdown]
# ---
# <img src="https://gitlab.com/bivl2ab/academico/cursos-uis/ai/ai-uis-student/raw/master/imgs/bannerThanks.jpg" alt="Drawing" style="width:700px;"/>
