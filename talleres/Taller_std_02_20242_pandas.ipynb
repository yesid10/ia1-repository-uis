# %% [markdown]
# <img src="https://gitlab.com/bivl2ab/academico/cursos-uis/ai/ai-uis-student/raw/master/imgs/banner_IA.png"  width="1000px" height="200px">
#
# # **Taller 02:  Pandas**
#
# ## **Outline**
#
# 1. [Ejercicio 1.](#eje1)
# 2. [Ejercicio 2.](#eje2)
# 3. [Ejercicio 3.](#eje3)
# 4. [Ejercicio 4.](#eje4)
# 5. [Ejercicio 5.](#eje5)

# %%
#@title **Execute this cell**
#@markdown Please include your student id
import sys
import inspect

# tuesday/wednesday 2:00 PM - E1
# thursday/friday 2:00 PM - E2
# thursday/friday 4:00 PM - F1

course_id = "E1" #@param {type:"string"}
group_id = "IA1-20242-"+course_id
assignment_id = group_id +'.taller_pandas'
student_id = "2151090" #@param {type:"string"}
"""
Put your student ID here

Example: student_id =  '2152145'
"""
print(group_id)

# %%
 #@title **Execute this cell**
#@markdown **UTILS**
#@markdown Please dont modify any line in this cell

import os
import json
import requests
from collections import namedtuple


Config = namedtuple('Config', ['server_name'])
config = Config(server_name='https://bivlabgrader.azurewebsites.net/api')


def check_solution_and_evaluate(assignment_id: str, student_func_str: str):

    # Set the endpoint and payload.
    payload = {
        'func_str': student_func_str,
        'assignment_id': assignment_id,
        'student_id': student_id
    }
    endpoint_url = config.server_name + '/CheckAndEvaluateSolution'
    # print(endpoint_url)

    # Make request to server with the data coming from the notebook.
    r = requests.post(endpoint_url, params=payload)
    pprint_json_response(r.json())
    return r


def pprint_json_response(response, indent=0):
    """Pretty print the response."""
    for key, value in response.items():
        print('\t' * indent + str(key.capitalize()))

        # If dictionary, do a recurrent call.
        if isinstance(value, dict):
            pprint_json_response(value, indent + 1)
        else:
            # Enumerate elements if list.
            if isinstance(value, list):
                if len(value) == 1:
                    print('\t' * (indent + 1) + str(value[0]))
                else:
                    for i, e in enumerate(value, start=1):
                        print('\t' * (indent + 1) + f'{i}. {e}')
            else:
                print('\t' * (indent + 1) + str(value))

# %%
#@title **Import libraries**

import numpy as np
import pandas as pd
np.random.seed(21)

# %% [markdown]
# # Pokemon dataset
# Para los siguientes ejercicios, se debe cargar correctamente el conjunto de datos `pokemon.csv` ( [Pokemon Dataset CSV](https://www.kaggle.com/code/ash316/learn-pandas-with-pokemons/input)
# ). Este conjunto de datos contiene pokemones con sus atributos relacionados, como nombre, tipos, generación etc.

# %%
import pandas as pd
url = "https://drive.google.com/uc?id=1WnFv_Oxqp45e_OoHwcAbZc6ieIWr7VRD"
df = pd.read_csv(url)

# %%
print(df.shape)
df.head()

# %% [markdown]
# ---
# # **Ejercicio 1**  <a name="eje1"></a>
# ---

# %% [markdown]
# Dado un conjunto de datos que contiene información sobre pokemones (`df`), incluyendo sus tipos primario (`['Type 1']`) y secundario (`['Type 2']`), cree una función que realice las siguientes tareas:
#
# - Explorar el Dataset: Calcule la **cantidad** total de pokemones (`cantidad_pokemones_con_dos_tipos`) que tienen tanto un tipo primario (`['Type 1']`) como un tipo secundario (`['Type 2']`).
#
# - Filtrar por Tipos Específicos: calcule un **DataFrame** (`pokemones_filtrados`) que contenga solo los pokemones cuyo tipo primario (`['Type 1']`) sea `'Water'` o `'Bug'`, y cuyo tipo secundario (`['Type 2']`) sea `'Grass'`.
#
# - Devuelva: las dimensiones del dataset, (`cantidad_pokemones_con_dos_tipos`) y (`pokemones_filtrados`)

# %%
#@title **code student**

def taller02_20242_p01(df):
    import pandas as pd
    pokemones_con_dos_tipos = None
    cantidad_pokemones_con_dos_tipos = len(None)
    pokemones_filtrados = df[((df[None] == None) | (df[None] == None)) & (df[None] == None)]
    return df.shape, cantidad_pokemones_con_dos_tipos, pokemones_filtrados

# %%
#@title **check your answer**
taller02_20242_p01(df)

# %%
#@title **send your answer**
student_func_str = inspect.getsource(taller02_20242_p01)
r = check_solution_and_evaluate(assignment_id, student_func_str)

# %% [markdown]
# ---
# # **Ejercicio 2**  <a name="eje2"></a>
# ---

# %% [markdown]
# Cree una función que agrupe a los Pokémon por su tipo primario `['Type 1']` y calcula el promedio de la velocidad `['Speed']` y la cantidad de Pokémon legendarios en cada grupo `['Legendary']`. Luego, filtre los grupos que tienen un promedio de velocidad superior a 70 y al menos dos Pokémon legendarios, y ordene los resultados por el promedio de velocidad en orden **descendente**.
#
# Finalmente, retorne un **DataFrame** con los resultados, mostrando el tipo primario (`'Type 1'`), el promedio de velocidad (`'Promedio Velocidad'`) y la cantidad de Pokémon legendarios (`'Cantidad Legendarios'`), ordenados de mayor a menor **promedio** de velocidad.
#
# <ins>**NOTA:**</ins> use un diccionario, con los keys exigidos en el párrafo anterior, para crear las columnas del DataFrame a retornar.

# %%
#@title **code student**

def taller02_20242_p02(df):
    import pandas as pd
    grupo = df.None(None)

    # Listas para almacenar resultados
    tipos = None
    promedios_velocidad = None
    cantidad_legendarios = None

    # Recorre cada grupo
    for tipo, datos in None:
        promedio_velocidad = datos[None].mean()
        cantidad_legendarios_en_tipo = datos[None].sum()

        # Solo agrega si cumple con las condiciones
        if promedio_velocidad > None and cantidad_legendarios_en_tipo >= None:
            tipos.append(None)
            promedios_velocidad.append(None)
            cantidad_legendarios.append(None)

    # Crea un DataFrame con los resultados
    resultado = pd.DataFrame({
        'None': tipos,
        'None': promedios_velocidad,
        'None': cantidad_legendarios
    })

    return resultado.sort_values(by='None', ascending=None)

# %%
#@title **check your answer**
print(taller02_20242_p02(df))
print(taller02_20242_p02(df).shape)
print(taller02_20242_p02(df)[["Promedio Velocidad", "Cantidad Legendarios"]].mean())

# %%
#@title **send your answer**
student_func_str = inspect.getsource(taller02_20242_p02)
r = check_solution_and_evaluate(assignment_id, student_func_str)

# %% [markdown]
# ---
# # **Ejercicio 3**  <a name="eje3"></a>
# ---

# %% [markdown]
# Para cada Pokémon, calcule la **correlación** entre las estadísticas de `'HP'`, `'Attack'` y `'Defense'`.
#
# **Devuelva** un nuevo DataFrame donde cada fila representa un Pokémon y las columnas contienen la correlación entre:
# - HP y Attack,
# - HP y Defense,
# - y Attack y Defense.

# %%
#@title **code student**

def taller02_20242_p03(df):
    import pandas as pd
    estadisticas = df[['None', 'None', 'None']]

    correlaciones = None.apply(
        lambda row: pd.Series({
            'None': estadisticas['None'].None(estadisticas['None']),
            'None': estadisticas['None'].None(estadisticas['None']),
            'None': estadisticas['None'].None(estadisticas['None'])
        }), axis=None
    )

    resultado = pd.concat([df['None'], None], axis=None)

    return resultado

# %%
#@title **check your answer**
print(taller02_20242_p03(df).shape)
print(taller02_20242_p03(df))
print(taller02_20242_p03(df)[["HP_Attack", "HP_Defense"]].mean())

# %%
#@title **send your answer**
student_func_str = inspect.getsource(taller02_20242_p03)
r = check_solution_and_evaluate(assignment_id, student_func_str)

# %% [markdown]
# ---
# # **Ejercicio 4**  <a name="eje4"></a>
# ---

# %% [markdown]
# Primero, **excluya** del análisis los Pokémon con la palabra "Mega" en su nombre `['Name']`.
#
# Luego, encuentre los Pokémon con la estadística más alta en las columnas (`'HP'`, `'Attack'`, `'Defense'`, `'Sp. Atk'`, `'Sp. Def'`, `'Speed'`).
#
# **Devuelva** un nuevo DataFrame que muestre el Pokémon con la estadística más alta para cada columna, junto con sus respectivas estadísticas.

# %%
#@title **code student**

def taller02_20242_p04(df):
    import pandas as pd
    df_sin_mega = df[~df['None'].str.None('None')]

    indices_max = {
        'None': df_sin_mega['None'].idxmax(),
        'None': df_sin_mega['None'].None(),
        'None': df_sin_mega['None'].None(),
        'None': df_sin_mega['None'].None(),
        'None': df_sin_mega['None'].None(),
        'None': df_sin_mega['None'].None()
    }

    datos_max = {estadistica: None.loc[idx] for estadistica, idx in None.items()}

    resultado = pd.None(None).T

    return resultado

# %%
#@title **check your answer**
print(taller02_20242_p04(df))
print(taller02_20242_p04(df).shape)
print(taller02_20242_p04(df)[["Total", "HP"]].mean())

# %%
#@title **send your answer**
student_func_str = inspect.getsource(taller02_20242_p04)
r = check_solution_and_evaluate(assignment_id, student_func_str)

# %% [markdown]
# ---
# # **Ejercicio 5**  <a name="eje5"></a>
# ---

# %% [markdown]
# Cree una función que simule un enfrentamiento entre dos equipos de Pokémon seleccionados aleatoriamente. Dado un conjunto de datos con información sobre Pokémon, la función debe:
#
# 1. **Excluir** los Pokémon con Mega evoluciones.
# 2. Seleccionar 6 Pokémon **al azar** para tu equipo y otros 6 para el equipo rival.
# 3. Comparar uno a uno los Pokémon de cada equipo utilizando la estadística `['Total']`.
# 4. Contar cuántos enfrentamientos gana cada equipo.
# 5. Para establecer el ganador (key `'winner'`) ud debe asignar a la variable `winner` los siguientes strings:
#   - `"Team 1 wins!"` si gana el equipo 1
#   - `"Team 2 wins!"` si gana el equipo 2
#   - `"It's a tie!"` si hay un empate
# 6. **Devuelva** un diccionario con los siguientes elementos:
#  - Los Pokémon seleccionados para cada equipo (key `'team_1'`), (key `'team_2'`) y sus respectivas estadísticas `['Name']` y `['Total']`.
#  - El equipo ganador (key `'winner'`) basándose en el número de victorias individuales.

# %%
#@title **code student**

def taller02_20242_p05(df):
    import numpy as np
    import pandas as pd
    np.random.seed(21) #NO BORRAR!

    df_no_mega = df[~df['None'].str.None('None')]

    team_1 = df_no_mega.None(None)
    team_2 = df_no_mega.None(None)

    team_1_wins = None
    team_2_wins = None

    for i in range(6):
        if team_1.iloc[i]['None'] > None.iloc[i]['None']:
            team_1_wins += None
        elif None.iloc[i]['None'] < team_2.iloc[i]['None']:
            team_2_wins += None

    if team_1_wins > team_2_wins:
        winner = None
    elif team_1_wins < team_2_wins:
        winner = None
    else:
        winner = None

    return {
        'None': team_1[['None', 'None']],
        'None': team_2[['None', 'None']],
        'None': winner
    }

# %%
#@title **check your answer**
taller02_20242_p05(df)

# %%
#@title **send your answer**
student_func_str = inspect.getsource(taller02_20242_p05)
r = check_solution_and_evaluate(assignment_id, student_func_str)
