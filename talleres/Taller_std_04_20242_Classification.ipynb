# %% [markdown]
# <img src="https://gitlab.com/bivl2ab/academico/cursos-uis/ai/ai-uis-student/raw/master/imgs/banner_IA.png"  width="1000px" height="200px">
#
# # **Taller 04: Classification**
#
# ## **Outline**
#
# 1. [Ejercicio 1.](#eje1)
# 2. [Ejercicio 2.](#eje2)
# 3. [Ejercicio 3.](#eje3)
# 4. [Ejercicio 4.](#eje4)

# %%
#@title **Execute this cell**
#@markdown Please include your student id
import sys
import inspect

group_id = "IA1-20242-E2" #@param {type:"string"}
assignment_id = group_id +'.taller_classification'
student_id = "2151090" #@param {type:"string"}
"""
Put your student ID here

Example: student_id =  '2152145'
"""
# Out:
# "\nPut your student ID here\n\nExample: student_id =  '2152145'\n"

# %%
 #@title **Execute this cell**
#@markdown **UTILS**
#@markdown Please dont modify any line in this cell

import os
import json
import requests
from collections import namedtuple


Config = namedtuple('Config', ['server_name'])
config = Config(server_name='https://bivlabgrader.azurewebsites.net/api')


def check_solution_and_evaluate(assignment_id: str, student_func_str: str):

    # Set the endpoint and payload.
    payload = {
        'func_str': student_func_str,
        'assignment_id': assignment_id,
        'student_id': student_id
    }
    endpoint_url = config.server_name + '/CheckAndEvaluateSolution'
    # print(endpoint_url)

    # Make request to server with the data coming from the notebook.
    r = requests.post(endpoint_url, params=payload)
    pprint_json_response(r.json())
    return r


def pprint_json_response(response, indent=0):
    """Pretty print the response."""
    for key, value in response.items():
        print('\t' * indent + str(key.capitalize()))

        # If dictionary, do a recurrent call.
        if isinstance(value, dict):
            pprint_json_response(value, indent + 1)
        else:
            # Enumerate elements if list.
            if isinstance(value, list):
                if len(value) == 1:
                    print('\t' * (indent + 1) + str(value[0]))
                else:
                    for i, e in enumerate(value, start=1):
                        print('\t' * (indent + 1) + f'{i}. {e}')
            else:
                print('\t' * (indent + 1) + str(value))

# %%
#@title **Import libraries**

import numpy as np
import pandas as pd
np.random.seed(21)

# %% [markdown]
# ---
# # **Ejercicio 1**  <a name="eje1"></a>
# ---

# %% [markdown]
# El dataset 'heart_data.csv' contiene información sobre factores demográficos, comportamientos de salud y marcadores biológicos que afectan el riesgo de enfermedad cardiovascular en adultos, con características como edad (age), género (gender), altura (height), peso (weight), presión arterial sistólica (ap_hi) y diastólica (ap_lo), colesterol (cholesterol), glucosa (gluc), tabaquismo (smoke), consumo de alcohol (alco) y actividad física (active), siendo el objetivo final clasificar la **presencia o ausencia** de enfermedad cardiovascular (`cardio`) mediante una regresión logística.
#
# Construya una función tal que:
# - El 80% del dataset se utilizará como train `X_train`, `y_train`
# - El 20% del dataset restante se utilizará como test: `X_test`, `y_test`
# - **Utilice** `train_test_split` con parámetros: `random_state=21`
# - Utilice para el proceso de **clasificación** al estimador `LogisticRegression` con parámetros: `max_iter=120`, `solver='newton-cg'`
# - Para mejorar el desempeño y la estabilidad del estimador, se transformaron las particiones `X_train` y `X_test` utilizando el método `StandardScaler`. NO elimine las líneas de código correspondientes a dicha transformación.
# - **Devuelva** el accuracy score
# - **Devuelva** el valor de la propiedad shape de `X_test`
#
# Estimador [LogisticRegression](https://scikit-learn.org/1.5/modules/generated/sklearn.linear_model.LogisticRegression.html)

# %%
#@title **code student**

def taller04_20242_p01(df):
  import numpy as np
  import pandas as pd
  from sklearn.model_selection import train_test_split
  from sklearn.linear_model import LogisticRegression
  from sklearn.metrics import accuracy_score
  from sklearn import preprocessing
  np.random.seed(21)

  X = None
  y = None

  X_train, X_test, y_train, y_test = None(None, None, None=None, random_state=21)

  model = None(None=None, None=None)

  #NO elimine estas tres lineas:
  scaler = preprocessing.StandardScaler().fit(X_train)
  X_train_scaled = scaler.transform(X_train)
  X_test_scaled = scaler.transform(X_test)

  model.None(None, None)
  y_pred = model.None(None)

  return None(None, None), None.shape

# %%
#@title **check your answer**
import pandas as pd

df = pd.read_csv("https://drive.google.com/uc?id=1RPBKsvkEdf5faU4hGHlqYa-x1aQfz3Ih")
taller04_20242_p01(df)

# %%
#@title **send your answer**
student_func_str = inspect.getsource(taller04_20242_p01)
r = check_solution_and_evaluate(assignment_id, student_func_str)

# %% [markdown]
# ---
# # **Ejercicio 2**  <a name="eje2"></a>
# ---

# %% [markdown]
# El dataset 'emails.csv' contiene una serie de palabras usadas en diferentes emails y se busca establecer si la frecuencia de estas palabras está asociada a correos spam o no-spam. Como características (`X`) se utilizaran todas las columnas, excepto la última (`Prediction`)
#
# Complete la siguiente función para que entrene un estimador teniendo en cuenta las siguientes consideraciones:
#
# - El 70% del dataset se utilizará como train.
# - El 30% del dataset restante se utilizará como test.
# - **Utilice** `train_test_split` con parámetros: `random_state=21`
# - Utilice SVC como estimador con parámetros: `C=5`, `kernel='linear'`
# - **Devuelva** el f1 score
# - **Devuelva** el valor de la propiedad shape de `X_test`
#
# Métrica [f1_score](https://scikit-learn.org/0.16/modules/generated/sklearn.metrics.f1_score.html)

# %%
#@title **code student**
def taller04_20242_p02(df):
  import numpy as np
  import pandas as pd
  from sklearn.svm import SVC
  from sklearn.metrics import f1_score
  from sklearn.model_selection import train_test_split
  np.random.seed(21)

  X = None[None[:-1]]
  y = None['None']
  X_train, X_test, y_train, y_test = None(None, None, None=None, random_state=21)
  svc = None(None=None, None=None)

  svc.None(None,None)
  y_pred = svc.None(None)

  return None(None, None), None.shape

# %%
#@title **check your answer**
import pandas as pd

df = pd.read_csv("https://drive.google.com/uc?id=1K7-5Yp8yet0GjPH6YkyLA3Qspc37PZO7")
taller04_20242_p02(df)

# %%
#@title **send your answer**
student_func_str = inspect.getsource(taller04_20242_p02)
r = check_solution_and_evaluate(assignment_id, student_func_str)

# %% [markdown]
# ---
# # **Ejercicio 3**  <a name="eje3"></a>
# ---

# %% [markdown]
# Desarrolle una función que utilice el conjunto de datos 'Pumpkin_Seeds_Dataset', el cual contiene características numéricas de semillas de calabaza. Usted debe desarrollar una tarea de **clasificación** según la clase de las semillas (`Class`). Utilice las **demás** columnas para obtener `X`.
#
# La función debe tener las siguientes características:
# - **Utilice** `train_test_split` con una partición de test de 10%, con parámetros: `random_state=21`
# - Entrenar un modelo de clasificación SVM con `kernel='rbf'`
# - **Devolver** el accuracy para el dataset escalado (método `StandardScaler`)
# - **Devolver** el accuracy **sin** escalar los datos de entrenamiento

# %%
#@title **code student**
def taller04_20242_p03(df):
  import numpy as np
  import pandas as pd
  from sklearn.model_selection import train_test_split
  from sklearn.preprocessing import StandardScaler
  from sklearn.svm import SVC
  from sklearn.metrics import accuracy_score
  np.random.seed(21)

  X = None[None[:-1]]
  y = None['None']

  X_train, X_test, y_train, y_test = None(None, None, None=None, random_state=21)
  svc = None(None=None)

  #datos sin escalar
  svc.None(None, None)
  y_pred = svc.None(None)
  accuracy_no_scaling = accuracy_score(None, None)

  #datos escalados
  scaler = StandardScaler()
  X_train_scaled = scaler.fit_transform(None)
  X_test_scaled = scaler.transform(None)

  svc.fit(X_train_scaled, None)
  y_pred_scaled = svc.None(None)
  accuracy_with_scaling = accuracy_score(None, None)

  # Retornar acc
  return accuracy_with_scaling, accuracy_no_scaling

# %%
#@title **check your answer**
import pandas as pd

df = pd.read_csv("https://drive.google.com/uc?id=1k9CwGQMt4XKLwob0Y4d0jqlf8Bl_bCLy")
taller04_20242_p03(df)

# %%
#@title **send your answer**
student_func_str = inspect.getsource(taller04_20242_p03)
r = check_solution_and_evaluate(assignment_id, student_func_str)

# %% [markdown]
# ---
# # **Ejercicio 4**  <a name="eje4"></a>
# ---

# %% [markdown]
# El dataset `Hate Speech and Offensive Language ` contiene información sobre tweets, que son clasificados (columna `class`) como: 0 (hate speech), 1 (offensive language) y 2 (neither). Desarrolle un modelo de clasificación para detectar tipos de discursos de odio en tweets.
#
# Tenga en cuenta los siguientes aspectos:
# - **Elimine** la columna (`tweet`)
# - Utilice todas las columnas para obtener `X`, y use (`class`) como ground truth
# - Divida los datos como entrenamiento y testeo, usando un 15% para test y parámetros `random_state=21`
# - Utilice el estimador `DecisionTreeClassifier` con parámetros `max_depth=3`
# - **Devuelva** el accuracy del modelo
# - **Devuelva** el <ins>promedio</ins> de los valores de la columna (`offensive_language_count`)

# %%
#@title **code student**
def taller04_20242_p04(df):
  import numpy as np
  import pandas as pd
  from sklearn.feature_extraction.text import CountVectorizer
  from sklearn.model_selection import train_test_split
  from sklearn.tree import DecisionTreeClassifier
  from sklearn.metrics import accuracy_score

  df = None.None("None", axis=1)
  X = None[None[:-1]]
  y = None['None']

  x_train, x_test, y_train, y_test = None(None, None, None=None, random_state=21)

  est = None(None=None)
  est.None(None, None)
  y_pred = est.None(None)
  score = accuracy_score(None, None)

  return score, None

# %%
#@title **check your answer**
import pandas as pd

df = pd.read_csv("https://drive.google.com/uc?id=1COANkorwfPHc5V6EfpgmdkfznhTUxOCU")
taller04_20242_p04(df)

# %%
#@title **send your answer**
student_func_str = inspect.getsource(taller04_20242_p04)
r = check_solution_and_evaluate(assignment_id, student_func_str)
