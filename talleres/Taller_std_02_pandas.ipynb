# %% [markdown]
# <img src="https://gitlab.com/bivl2ab/academico/cursos-uis/ai/ai-uis-student/raw/master/imgs/banner_IA.png"  width="1000px" height="200px">
#
# # **Taller 02:  Pandas**
#
# ## **Outline**
#
# 1. [Ejercicio 1.](#eje1)
# 2. [Ejercicio 2.](#eje2)
# 2. [Ejercicio 3.](#eje3)
# 2. [Ejercicio 4.](#eje4)
# 2. [Ejercicio 5.](#eje5)

# %%
#@title **Execute this cell**
#@markdown Please include your student id
import sys
import inspect

group_id = "IA1-20221-H1" #@param {type:"string"}
assignment_id = group_id +'.taller_pandas'
student_id = "2218109" #@param {type:"string"}
"""
Put your student ID here

Example: student_id =  '2152145'
"""
# Out:
# "\nPut your student ID here\n\nExample: student_id =  '2152145'\n"

# %%
 #@title **Execute this cell**
#@markdown **UTILS**
#@markdown Please dont modify any line in this cell

import os
import json
import requests
from collections import namedtuple


Config = namedtuple('Config', ['server_name'])
config = Config(server_name='https://bivlabgrader.azurewebsites.net/api')


def check_solution_and_evaluate(assignment_id: str, student_func_str: str):

    # Set the endpoint and payload.
    payload = {
        'func_str': student_func_str,
        'assignment_id': assignment_id,
        'student_id': student_id
    }
    endpoint_url = config.server_name + '/CheckAndEvaluateSolution'
    # print(endpoint_url)

    # Make request to server with the data coming from the notebook.
    r = requests.post(endpoint_url, params=payload)
    pprint_json_response(r.json())
    return r


def pprint_json_response(response, indent=0):
    """Pretty print the response."""
    for key, value in response.items():
        print('\t' * indent + str(key.capitalize()))

        # If dictionary, do a recurrent call.
        if isinstance(value, dict):
            pprint_json_response(value, indent + 1)
        else:
            # Enumerate elements if list.
            if isinstance(value, list):
                if len(value) == 1:
                    print('\t' * (indent + 1) + str(value[0]))
                else:
                    for i, e in enumerate(value, start=1):
                        print('\t' * (indent + 1) + f'{i}. {e}')
            else:
                print('\t' * (indent + 1) + str(value))

# %%
#@title **Import libraries**

import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
#@title Los **Ejercicios 1 - 5** utilizan el siguiente dataset. 
#@markdown Cada fila de este dataset representa una propiedad que tiene asociada una serie de datos como inversión, año, comuna, entre otros.
#@markdown Cargue los datos y recuerde que están en un dataframe "d"

d = pd.read_csv("https://gitlab.com/bivl2ab/academico/cursos-uis/ai/ai-uis-student/-/raw/master/data/inversion_comunas_agregado.csv", sep=",")
d.head(3)
# Out:
#    CodDependencia                                    Dependencia  \
# 0           201.0  Secretaría de Gobierno y Gestión del Gabinete
# 1           201.0  Secretaría de Gobierno y Gestión del Gabinete
# 2           201.0  Secretaría de Gobierno y Gestión del Gabinete
#
#    Tipo de Inversión  CodBPIN  \
# 0                0.0  30219.0
# 1                0.0  40048.0
# 2                0.0  40053.0
#
#                                 Nombre_proy_Ajustado  Comuna  \
# 0  Apoyo Al Funcionamiento De Centros De Concilia...    99.0
# 1                                   Guias Ciduadanos     7.0
# 2                                       Plan Desarme    50.0
#
#                    NomComuna    Inversion     Año        Corte  \
# 0             Toda la Ciudad   21,881,223  2008.0  31-Dic-2008
# 1                    Robledo  135,598,200  2008.0  31-Dic-2008
# 2  San Sebastián de Palmitas    3,068,101  2008.0  31-Dic-2008
#
#    Codigo Dependencia Nombre Proyecto Nombre Comuna
# ...

# %% [markdown]
# ---
# # **Ejercicio 1**  <a name="eje1"></a>
# ---
#
# Escriba una función que reciba el dataframe, reemplace las celdas vacias de la columna ``Comuna`` con el valor 100 y reemplace las celdas vacias de la columna ``Inversión`` con el valor 0
#
# - Retorne un nuevo dataframe solo con las columnas ``Inversión`` y ``Comuna``.

# %%
def replace_dataframe(data):
  #  Importing allowed libraries
  import numpy as np
  import pandas as pd
  
  """Put your code here"""
  
  return

# %%
 #@title **send your answer**
student_func_str = inspect.getsource(replace_dataframe)
r = check_solution_and_evaluate(assignment_id, student_func_str)

# %% [markdown]
# ---
# # **Ejercicio 2**  <a name="eje2"></a>
# ---
# - Escriba una función que reciba el dataframe ``d``.
# - Elimine las filas donde ``Inversion`` o ``Comuna`` no tienen valores.
# - Convertir la columna ``Inversion`` en una columna donde los valores son tipo float.
# - Convertir la columna ``Comuna`` y ``Año`` en columnaa de valores son enteros.
#
# El resultado debe ser un dataframe con 3 columnas: ``Comuna``,``Año`` e ``Inversion``.

# %%
def dataframe_statistics(data):
  #  Importing allowed libraries
  import pandas as pd
  
  """Put your code here"""
    
  return

# %%
 #@title **send your answer**
student_func_str = inspect.getsource(dataframe_statistics)
r = check_solution_and_evaluate(assignment_id, student_func_str)

# %% [markdown]
# ---
# # **Ejercicio 3**  <a name="eje3"></a>
# ---
#
#
# - Escriba una función que reciba el dataset ``d`` y calcule la inversión promedio en cada comuna para el año 2016.
# - Ordenar de mayor a menor inversión.
#
# - Debe retornar un dataframe con dos columnas, la primera ``Comuna`` y la segunda ``mean`` con los vaalores promedio por comuna.

# %%
def avg_investment(data):
  #  Importing allowed libraries
  import pandas as pd
  
  """Put your code here"""
    
  return

# %%
 #@title **send your answer**
student_func_str = inspect.getsource(avg_investment)
r = check_solution_and_evaluate(assignment_id, student_func_str)

# %% [markdown]
# ---
# # **Ejercicio 4**  <a name="eje4"></a>
# ---
#
# Note que los valores son dificiles de interpretar por su gran magnitud. Esto se debe a que estan en pesos y son cifra grandes. Ahora el reto es:
#
# - A partir del dataset ``d``, crear un dataset donde la variable inversión represente la **cantidad millones invertidos** y con esto retornar un dataframe agrupado por comunas.
#
# - Las columnas que debe contener son: la primera ``Comuna``, las demás ``max``, ``min`` y ``mean`` (en este orden), que representan el maximo, mínimo y el promedio de la cantidad de millones invertidos en cada comuna en todos los años de los que se tiene registro en el dataset.

# %%
def maxmin_d(data):  
  #  Importing allowed libraries
  import pandas as pd
  """Put your code here"""
    
  return

# %%
 #@title **send your answer**
student_func_str = inspect.getsource(maxmin_d)
r = check_solution_and_evaluate(assignment_id, student_func_str)

# %% [markdown]
# ---
# # **Ejercicio 5**  <a name="eje5"></a>
# ---
#
# Las Comunas con código menor o igual a 16 representan comunas de tipo "Urbana" las demás son de tipo "Rural".
#
# A partir del dataset ``d``, construya un dataframe que contenga la inversión total en cada tipo de comuna ("Urbana" o "Rural") en el año 2016.
#
# - Debe devolver un dataframe con dos columnas: ``tipo_comuna`` y ``sum``. Note que el dataframe a devolver tendrá dos filas, una para cada tipo de comuna.

# %%
def inversion_tipo(data):  
  #  Importing allowed libraries
  import pandas as pd
  
  """Put your code here"""
    
  return

# %%
 #@title **send your answer**
student_func_str = inspect.getsource(inversion_tipo)
r = check_solution_and_evaluate(assignment_id, student_func_str)

# %% [markdown]
# ---
# <img src="https://gitlab.com/bivl2ab/academico/cursos-uis/ai/ai-uis-student/raw/master/imgs/bannerThanks.jpg" alt="Drawing" style="width:700px;"/>
