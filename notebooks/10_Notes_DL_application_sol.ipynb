# %% [markdown]
# <img src="https://gitlab.com/bivl2ab/academico/cursos-uis/ai/ai-uis-student/raw/master/imgs/speech.jpeg" alt="Drawing" style="width:1700px;">
#
#
#
# # <center> 10. Complement lecture on Deep neuronal networks </center>
#
#
# ### Additional applications
#
# From DNN lecture seen on previous class, try to approach this algorithms in other application: audio recognition

# %%
#@title 1. MONTAR EL DRIVE { display-mode: "form" }
import os
from google.colab import drive
drive.mount('/content/drive')
os.chdir('/content/drive/My Drive/course-IA1/ai-uis-student')
print(os.getcwd())
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/course-IA1/ai-uis-student

# %%
#@title 2. LOAD LIB { display-mode: "form" }
#@markdown Here is important to change to GPU  
import os
import tensorflow as tf
from tensorflow import keras
print(tf.__version__)
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#!pip install librosa
# Out:
# 2.2.0

# %% [markdown]
# A typical library to read and rpocess audio is `librosa`. We firstly install library and then we can start to work.

# %% [markdown]
# # 1. Free Spoken Digit Dataset (FSDD)
# ## The speech MNIST
#
# A simple audio/speech dataset consisting of recordings of spoken digits in wav files at 8kHz. The recordings are trimmed so that they have near minimal silence at the beginnings and ends [Source](https://github.com/Jakobovski/free-spoken-digit-dataset)
#
# ### Dataset description
#
# - 4 speakers
# - 2.000 recordings (50 of each digit per speaker)
# - English pronunciations
#
# An example of the dataset: `{digitLabel}_{speakerName}_{index}.wav` Example: `7_jackson_32.wav`

# %%
#@title **code** reproduce an audio example
file_name = "7_jackson_40.wav" #@param {type:"string"}

import IPython.display as ipd
ipd.Audio('data/fsdd/'+file_name)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import librosa
wav, sr = librosa.load('data/fsdd/8_jackson_40.wav', sr=None)
print( 'sr:', sr)
print( 'wav shape:', wav.shape)

plt.plot(wav);
# Out:
# sr: 8000
# wav shape: (3532,)

# %%
import librosa.display
plt.figure(figsize=(14, 5))
librosa.display.waveplot(wav, sr=sr)

# %% [markdown]
# more specifically..

# %%
plt.plot(wav[2000:5000])

# %% [markdown]
# ## <span style="color:orange">Student Challenge </span>:
# - Read the FSDD audio dataset, using `librosa` library
#   - Built the $\mathbf{X}$ $\in$ $\mathbb{R}^{n \times m}$ matrix. The $n$ rows are the examples (20000) and $m$ colums is the dimension of each file.
#   - Built the $\mathbf{y} \in \mathbb{R}^{n}$ corresponding to classes labels.
#
#
# ** Pay attention that all files dont have the same dimension. Then, we add zeros to obtain files with same size. This process is named `padding`
# - For so, you can use next function.

# %%
def func_padding(wav, pad_size=2000):
    if wav.shape[0] > pad_size:
        return wav[0: pad_size]
    else:
        return np.hstack((wav, np.zeros(pad_size - wav.shape[0])))

# %% [markdown]
# Consider only take three different values.

# %%
def get_XyData(DATA_DIR = 'data/fsdd/', pad_size=200):

  X =[]
  y =[]
  
  for fname in os.listdir(DATA_DIR):
    struct = fname.split('_')
    digit = struct[0]
    if (digit is '0') or (digit is '1'):
      wav, sr = librosa.load(DATA_DIR + fname)
      padded = func_padding(wav, pad_size)
      #padded = padded.reshape(padded.shape[0],1)
      X.append(padded)
      y.append(digit)   

  return np.vstack(X), np.array(y)

# %%
X, y = get_XyData(DATA_DIR = 'data/fsdd/')

print( 'X:', X.shape)
print( 'y:', y.shape)
# Out:
# X: (400, 200)
# y: (400,)

# %% [markdown]
# ## <span style="color:orange">Student Challenge </span>:
# - Modify `get_XyData` to only classify two classes (read all classes can take a lot of time)
# - Split data on training (60% ) and test (40%).

# %%
from sklearn.model_selection import train_test_split
test_size = 0.4
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)
print(X_train.shape, X_test.shape)
print(X_train[0].shape)
print(y_train.shape, y_test.shape)
# Out:
# (240, 200) (160, 200)
# (200,)
# (240,) (160,)

# %% [markdown]
# THE ONE-HOT-ENCODING!

# %%
y_train_ohe = tf.keras.utils.to_categorical(y_train, num_classes=2)
y_test_ohe = tf.keras.utils.to_categorical(y_test, num_classes=2)
print(y_train_ohe.shape, y_test_ohe.shape)
# Out:
# (240, 2) (160, 2)

# %% [markdown]
# ## <span style="color:orange">Student Challenge </span>:
# - Built a DNN with the following configuration:
#     - the input is the `x[0]` dimension
#     - A hidden layer of 128 neurons.
#     - the output is `softmax` layer with `10` outputs, corresponding to classes
#     - print the summary

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten( input_shape= X_train[0].shape),
    tf.keras.layers.Dense(128, activation='relu'),                             
    tf.keras.layers.Dense(2, activation='sigmoid')     #softmax for multiple classes               
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 200)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               25728
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 25,986
# Trainable params: 25,986
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(), 
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# fit the model wit a  `batch_size=10` and `epochs=15`

# %%
model.fit(X_train, y_train_ohe, epochs=5)
# Out:
# Epoch 1/5
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6928 - accuracy: 0.5250
# Epoch 2/5
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6894 - accuracy: 0.5792
# Epoch 3/5
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6871 - accuracy: 0.5708
# Epoch 4/5
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6839 - accuracy: 0.5625
# Epoch 5/5
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6816 - accuracy: 0.5583

# %%
test_loss, test_acc = model.evaluate(X_test, y_test_ohe)

print( 'Test accuracy:', test_acc, " test_loss: ", test_loss)
# Out:
# 5/5 [==============================] - 0s 2ms/step - loss: 0.6970 - accuracy: 0.4750
# Test accuracy: 0.4749999940395355  test_loss:  0.6970170140266418

# %% [markdown]
# Compile the model, using the next configuration

# %%
history = model.fit(X_train,
          y_train_ohe,
          epochs=10,
          batch_size=40,
          validation_data=(X_test, y_test_ohe))

plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
# Out:
# Epoch 1/10
# 6/6 [==============================] - 0s 17ms/step - loss: 0.6785 - accuracy: 0.5458 - val_loss: 0.6979 - val_accuracy: 0.4625
# Epoch 2/10
# 6/6 [==============================] - 0s 7ms/step - loss: 0.6765 - accuracy: 0.5500 - val_loss: 0.6987 - val_accuracy: 0.4625
# Epoch 3/10
# 6/6 [==============================] - 0s 6ms/step - loss: 0.6742 - accuracy: 0.5500 - val_loss: 0.6996 - val_accuracy: 0.4812
# Epoch 4/10
# 6/6 [==============================] - 0s 7ms/step - loss: 0.6718 - accuracy: 0.5500 - val_loss: 0.7007 - val_accuracy: 0.4812
# Epoch 5/10
# 6/6 [==============================] - 0s 7ms/step - loss: 0.6695 - accuracy: 0.5542 - val_loss: 0.7018 - val_accuracy: 0.4875
# Epoch 6/10
# 6/6 [==============================] - 0s 6ms/step - loss: 0.6672 - accuracy: 0.5625 - val_loss: 0.7029 - val_accuracy: 0.4938
# Epoch 7/10
# 6/6 [==============================] - 0s 7ms/step - loss: 0.6647 - accuracy: 0.5667 - val_loss: 0.7040 - val_accuracy: 0.4938
# Epoch 8/10
# 6/6 [==============================] - 0s 6ms/step - loss: 0.6626 - accuracy: 0.5792 - val_loss: 0.7056 - val_accuracy: 0.4938
# Epoch 9/10
# 6/6 [==============================] - 0s 6ms/step - loss: 0.6604 - accuracy: 0.5792 - val_loss: 0.7070 - val_accuracy: 0.5000
# Epoch 10/10
# 6/6 [==============================] - 0s 6ms/step - loss: 0.6581 - accuracy: 0.5833 - val_loss: 0.7085 - val_accuracy: 0.4812

# %% [markdown]
# ## <span style="color:orange">Student Challenge </span>:
# - what happened? ...
# - Now try to scale data...a very important issue on ML but specially on DL. Uses:
#
# ```
#  StandardScaler()
# ```
# and try!!!
#
# - Try with other DNN network more conected:
#     - hidden layer of 10000
# - Try with other DNN network **more deeply**:
#     - hidden layer of 1500
#     - hidden layer of 500
#     - hidden layer of 1500
# - Try also changing padding parameter to obtaine samples with size: [5000, 20000]

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten( input_shape= (X_train[0].shape)),
    tf.keras.layers.Dense(5000, activation=tf.nn.relu),
    tf.keras.layers.Dense(2500, activation=tf.nn.relu),
    tf.keras.layers.Dense(1500, activation=tf.nn.relu),
    tf.keras.layers.Dense(500, activation=tf.nn.relu),
    tf.keras.layers.Dense(256, activation=tf.nn.relu),
    tf.keras.layers.Dense(128, activation=tf.nn.relu),
    tf.keras.layers.Dense(2, activation=tf.nn.softmax)
])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 200)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 5000)              1005000
# _________________________________________________________________
# dense_3 (Dense)              (None, 2500)              12502500
# _________________________________________________________________
# dense_4 (Dense)              (None, 1500)              3751500
# _________________________________________________________________
# dense_5 (Dense)              (None, 500)               750500
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               128256
# _________________________________________________________________
# dense_7 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_8 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 18,170,910
# Trainable params: 18,170,910
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(), 
              loss='binary_crossentropy',
              metrics=['accuracy'])
history = model.fit(X_train,
          y_train_ohe,
          epochs=40,
          batch_size=100,
          validation_data=(X_test, y_test_ohe))

plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
# Out:
# Epoch 1/40
# 3/3 [==============================] - 0s 49ms/step - loss: 0.6919 - accuracy: 0.4875 - val_loss: 0.7010 - val_accuracy: 0.5000
# Epoch 2/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6841 - accuracy: 0.5333 - val_loss: 0.7104 - val_accuracy: 0.4875
# Epoch 3/40
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6976 - accuracy: 0.5292 - val_loss: 0.7009 - val_accuracy: 0.5125
# Epoch 4/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6577 - accuracy: 0.5583 - val_loss: 0.7581 - val_accuracy: 0.5063
# Epoch 5/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6379 - accuracy: 0.6417 - val_loss: 0.8078 - val_accuracy: 0.5000
# Epoch 6/40
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6259 - accuracy: 0.5958 - val_loss: 0.9240 - val_accuracy: 0.4938
# Epoch 7/40
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6053 - accuracy: 0.6167 - val_loss: 1.2486 - val_accuracy: 0.4750
# Epoch 8/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6057 - accuracy: 0.6083 - val_loss: 0.9081 - val_accuracy: 0.5000
# Epoch 9/40
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6090 - accuracy: 0.6083 - val_loss: 0.8041 - val_accuracy: 0.5375
# Epoch 10/40
# 3/3 [==============================] - 0s 16ms/step - loss: 0.5879 - accuracy: 0.6333 - val_loss: 0.8702 - val_accuracy: 0.5437
# Epoch 11/40
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6022 - accuracy: 0.5583 - val_loss: 1.0764 - val_accuracy: 0.5250
# Epoch 12/40
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6117 - accuracy: 0.6042 - val_loss: 0.8824 - val_accuracy: 0.5312
# Epoch 13/40
# 3/3 [==============================] - 0s 16ms/step - loss: 0.5976 - accuracy: 0.5917 - val_loss: 0.8107 - val_accuracy: 0.5375
# Epoch 14/40
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6259 - accuracy: 0.5625 - val_loss: 0.8417 - val_accuracy: 0.5437
# Epoch 15/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.6024 - accuracy: 0.5833 - val_loss: 0.9136 - val_accuracy: 0.5312
# Epoch 16/40
# 3/3 [==============================] - 0s 16ms/step - loss: 0.5866 - accuracy: 0.6292 - val_loss: 1.0566 - val_accuracy: 0.5250
# Epoch 17/40
# 3/3 [==============================] - 0s 15ms/step - loss: 0.5774 - accuracy: 0.6292 - val_loss: 1.1321 - val_accuracy: 0.5250
# Epoch 18/40
# 3/3 [==============================] - 0s 15ms/step - loss: 0.5544 - accuracy: 0.6333 - val_loss: 1.1096 - val_accuracy: 0.5375
# Epoch 19/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.5404 - accuracy: 0.6708 - val_loss: 1.0597 - val_accuracy: 0.5625
# Epoch 20/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.5142 - accuracy: 0.7333 - val_loss: 1.0871 - val_accuracy: 0.5625
# Epoch 21/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.4879 - accuracy: 0.7417 - val_loss: 1.3568 - val_accuracy: 0.5125
# Epoch 22/40
# 3/3 [==============================] - 0s 16ms/step - loss: 0.4711 - accuracy: 0.6708 - val_loss: 1.5588 - val_accuracy: 0.5813
# Epoch 23/40
# 3/3 [==============================] - 0s 16ms/step - loss: 0.5045 - accuracy: 0.7000 - val_loss: 1.5004 - val_accuracy: 0.5000
# Epoch 24/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.4613 - accuracy: 0.7542 - val_loss: 1.5652 - val_accuracy: 0.5250
# Epoch 25/40
# 3/3 [==============================] - 0s 16ms/step - loss: 0.4546 - accuracy: 0.7625 - val_loss: 1.4312 - val_accuracy: 0.5562
# Epoch 26/40
# 3/3 [==============================] - 0s 16ms/step - loss: 0.4381 - accuracy: 0.7958 - val_loss: 1.3995 - val_accuracy: 0.5000
# Epoch 27/40
# 3/3 [==============================] - 0s 15ms/step - loss: 0.4145 - accuracy: 0.7667 - val_loss: 1.5283 - val_accuracy: 0.5250
# Epoch 28/40
# 3/3 [==============================] - 0s 16ms/step - loss: 0.3691 - accuracy: 0.7917 - val_loss: 1.9519 - val_accuracy: 0.5250
# Epoch 29/40
# 3/3 [==============================] - 0s 16ms/step - loss: 0.3614 - accuracy: 0.8042 - val_loss: 2.1054 - val_accuracy: 0.5125
# Epoch 30/40
# 3/3 [==============================] - 0s 16ms/step - loss: 0.3744 - accuracy: 0.7917 - val_loss: 1.8920 - val_accuracy: 0.5437
# Epoch 31/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.3353 - accuracy: 0.8375 - val_loss: 2.3150 - val_accuracy: 0.5063
# Epoch 32/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.3574 - accuracy: 0.8250 - val_loss: 1.8300 - val_accuracy: 0.5188
# Epoch 33/40
# 3/3 [==============================] - 0s 17ms/step - loss: 0.3793 - accuracy: 0.7792 - val_loss: 2.1568 - val_accuracy: 0.5125
# Epoch 34/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.4009 - accuracy: 0.7875 - val_loss: 2.0074 - val_accuracy: 0.5188
# Epoch 35/40
# 3/3 [==============================] - 0s 20ms/step - loss: 0.3651 - accuracy: 0.7833 - val_loss: 2.1675 - val_accuracy: 0.5250
# Epoch 36/40
# 3/3 [==============================] - 0s 19ms/step - loss: 0.3951 - accuracy: 0.7833 - val_loss: 2.0194 - val_accuracy: 0.5188
# Epoch 37/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.3726 - accuracy: 0.7792 - val_loss: 1.5558 - val_accuracy: 0.5375
# Epoch 38/40
# 3/3 [==============================] - 0s 18ms/step - loss: 0.4375 - accuracy: 0.7958 - val_loss: 1.4231 - val_accuracy: 0.5375
# Epoch 39/40
# 3/3 [==============================] - 0s 16ms/step - loss: 0.3750 - accuracy: 0.8042 - val_loss: 1.4765 - val_accuracy: 0.5250
# Epoch 40/40
# 3/3 [==============================] - 0s 16ms/step - loss: 0.3520 - accuracy: 0.8042 - val_loss: 1.5427 - val_accuracy: 0.5562

# %% [markdown]
# ## <span style="color:orange">Student Challenge </span>:
#
# - Raw signals are not good candidate to represent audio. So, we can compute a natural feature of this sign that is the FFT
#
# See an example

# %%
import librosa.display as dis
D = librosa.amplitude_to_db(np.abs(librosa.stft(wav)), ref=np.max)
print( D.shape)
print( D.reshape(D.shape[0]*D.shape[1]).shape)
dis.specshow(D, y_axis='linear');
# Out:
# (1025, 7)
# (7175,)

# %% [markdown]
# In audio one of the more relevant and compact features is the `melspectrogram` [wiki](https://es.wikipedia.org/wiki/MFCC)

# %%
SP = librosa.feature.melspectrogram(wav)
print( SP.shape)
plt.matshow(SP.T)
# Out:
# (128, 7)

# %% [markdown]
# ## <span style="color:orange">Student Challenge </span>:
#
# Built a function to recover $\mathbf{X},\mathbf{y}$ but using melspectrogram as descriptor.
#
# - Do a padding of max = 1000

# %%
def get_Xy_Features(DATA_DIR = 'data/fsdd/', pad_size=500):
    
    X = []
    y = []

    for fname in os.listdir(DATA_DIR):
        struct = fname.split('_')
        digit = struct[0]
        if (digit is '0') or (digit is '1'):
          wav, sr = librosa.load(DATA_DIR + fname)
          D = librosa.feature.melspectrogram(wav)
          padded = func_padding(D.reshape(D.shape[0]*D.shape[1]), pad_size)
          #print( D.reshape(D.shape[0]*D.shape[1]).shape)
          #print( padded.shape)
          X.append(padded)        
          y.append(digit)
    return np.vstack(X), np.array(y)

# %%
from sklearn.model_selection import train_test_split
X, y = get_Xy_Features(DATA_DIR = 'data/fsdd/')
print( 'X:', X.shape)
print( 'y:', y.shape)
test_size = 0.1
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)
print(X_train.shape, y_train.shape)
print(X_train[0].shape)
# Out:
# X: (400, 500)
# y: (400,)
# (360, 500) (360,)
# (500,)

# %%
y_train_ohe = tf.keras.utils.to_categorical(y_train, num_classes=2)
y_test_ohe = tf.keras.utils.to_categorical(y_test, num_classes=2)
print(y_train_ohe.shape, y_test_ohe.shape)
# Out:
# (360, 2) (40, 2)

# %% [markdown]
# Now train a DNN model:
#     - Using an input of 1000.
#     - A hidden layer of 2000 neurons
#     - A hidden layer of 1000 neurons
#     - A hidden layer of 500 neurons
#     - A sof max layer of 10

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten( input_shape= X_train[0].shape),
    tf.keras.layers.Dense(128, activation=tf.nn.relu),                             
    tf.keras.layers.Dense(2, activation=tf.nn.softmax)                    
])



model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_2 (Flatten)          (None, 500)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 128)               64128
# _________________________________________________________________
# dense_10 (Dense)             (None, 2)                 258
# =================================================================
# Total params: 64,386
# Trainable params: 64,386
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(), 
              loss='binary_crossentropy',
              metrics=['accuracy'])
history = model.fit(X_train,
          y_train_ohe,
          epochs=40,
          batch_size=100,
          validation_data=(X_test, y_test_ohe))
                           
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
# Out:
# Epoch 1/40
# 4/4 [==============================] - 0s 26ms/step - loss: 2.8580 - accuracy: 0.5444 - val_loss: 1.3664 - val_accuracy: 0.6750
# Epoch 2/40
# 4/4 [==============================] - 0s 9ms/step - loss: 1.6162 - accuracy: 0.6806 - val_loss: 0.5609 - val_accuracy: 0.9000
# Epoch 3/40
# 4/4 [==============================] - 0s 9ms/step - loss: 0.9926 - accuracy: 0.7944 - val_loss: 0.4640 - val_accuracy: 0.9500
# Epoch 4/40
# 4/4 [==============================] - 0s 9ms/step - loss: 0.8208 - accuracy: 0.8361 - val_loss: 0.4619 - val_accuracy: 0.9500
# Epoch 5/40
# 4/4 [==============================] - 0s 9ms/step - loss: 0.8082 - accuracy: 0.8611 - val_loss: 0.4550 - val_accuracy: 0.9500
# Epoch 6/40
# 4/4 [==============================] - 0s 10ms/step - loss: 0.7820 - accuracy: 0.8722 - val_loss: 0.4055 - val_accuracy: 0.9500
# Epoch 7/40
# 4/4 [==============================] - 0s 10ms/step - loss: 0.7693 - accuracy: 0.8778 - val_loss: 0.3604 - val_accuracy: 0.9500
# Epoch 8/40
# 4/4 [==============================] - 0s 9ms/step - loss: 0.7596 - accuracy: 0.8889 - val_loss: 0.3255 - val_accuracy: 0.9500
# Epoch 9/40
# 4/4 [==============================] - 0s 8ms/step - loss: 0.7519 - accuracy: 0.8944 - val_loss: 0.2859 - val_accuracy: 0.9500
# Epoch 10/40
# 4/4 [==============================] - 0s 10ms/step - loss: 0.7447 - accuracy: 0.8944 - val_loss: 0.2554 - val_accuracy: 0.9500
# Epoch 11/40
# 4/4 [==============================] - 0s 9ms/step - loss: 0.7380 - accuracy: 0.9000 - val_loss: 0.2308 - val_accuracy: 0.9500
# Epoch 12/40
# 4/4 [==============================] - 0s 9ms/step - loss: 0.7317 - accuracy: 0.9083 - val_loss: 0.2126 - val_accuracy: 0.9500
# Epoch 13/40
# 4/4 [==============================] - 0s 10ms/step - loss: 0.7256 - accuracy: 0.9111 - val_loss: 0.1996 - val_accuracy: 0.9500
# Epoch 14/40
# 4/4 [==============================] - 0s 9ms/step - loss: 0.7204 - accuracy: 0.9139 - val_loss: 0.1888 - val_accuracy: 0.9500
# Epoch 15/40
# 4/4 [==============================] - 0s 8ms/step - loss: 0.7148 - accuracy: 0.9139 - val_loss: 0.1785 - val_accuracy: 0.9500
# Epoch 16/40
# 4/4 [==============================] - 0s 9ms/step - loss: 0.7095 - accuracy: 0.9139 - val_loss: 0.1685 - val_accuracy: 0.9500
# Epoch 17/40
# 4/4 [==============================] - 0s 9ms/step - loss: 0.7047 - accuracy: 0.9139 - val_loss: 0.1577 - val_accuracy: 0.9500
# Epoch 18/40
# 4/4 [==============================] - 0s 8ms/step - loss: 0.6998 - accuracy: 0.9167 - val_loss: 0.1503 - val_accuracy: 0.9750
# Epoch 19/40
# 4/4 [==============================] - 0s 9ms/step - loss: 0.6952 - accuracy: 0.9194 - val_loss: 0.1427 - val_accuracy: 0.9750
# Epoch 20/40
# 4/4 [==============================] - 0s 9ms/step - loss: 0.6907 - accuracy: 0.9222 - val_loss: 0.1347 - val_accuracy: 0.9750
# Epoch 21/40
# 4/4 [==============================] - 0s 8ms/step - loss: 0.6863 - accuracy: 0.9250 - val_loss: 0.1298 - val_accuracy: 1.0000
# Epoch 22/40
# 4/4 [==============================] - 0s 9ms/step - loss: 0.6821 - accuracy: 0.9250 - val_loss: 0.1244 - val_accuracy: 1.0000
# Epoch 23/40
# 4/4 [==============================] - 0s 11ms/step - loss: 0.6779 - accuracy: 0.9278 - val_loss: 0.1209 - val_accuracy: 1.0000
# Epoch 24/40
# 4/4 [==============================] - 0s 10ms/step - loss: 0.6738 - accuracy: 0.9278 - val_loss: 0.1182 - val_accuracy: 1.0000
# Epoch 25/40
# 4/4 [==============================] - 0s 8ms/step - loss: 0.6701 - accuracy: 0.9278 - val_loss: 0.1156 - val_accuracy: 1.0000
# Epoch 26/40
# 4/4 [==============================] - 0s 9ms/step - loss: 0.6664 - accuracy: 0.9278 - val_loss: 0.1138 - val_accuracy: 1.0000
# Epoch 27/40
# 4/4 [==============================] - 0s 9ms/step - loss: 0.6628 - accuracy: 0.9278 - val_loss: 0.1150 - val_accuracy: 1.0000
# Epoch 28/40
# 4/4 [==============================] - 0s 9ms/step - loss: 0.6595 - accuracy: 0.9306 - val_loss: 0.1376 - val_accuracy: 0.9750
# Epoch 29/40
# 4/4 [==============================] - 0s 10ms/step - loss: 0.6561 - accuracy: 0.9306 - val_loss: 0.1967 - val_accuracy: 0.9750
# Epoch 30/40
# 4/4 [==============================] - 0s 10ms/step - loss: 0.6561 - accuracy: 0.9306 - val_loss: 0.3991 - val_accuracy: 0.9500
# Epoch 31/40
# 4/4 [==============================] - 0s 9ms/step - loss: 0.6628 - accuracy: 0.9278 - val_loss: 0.6040 - val_accuracy: 0.9500
# Epoch 32/40
# 4/4 [==============================] - 0s 11ms/step - loss: 0.6173 - accuracy: 0.9333 - val_loss: 0.6005 - val_accuracy: 0.9500
# Epoch 33/40
# 4/4 [==============================] - 0s 9ms/step - loss: 0.5389 - accuracy: 0.9361 - val_loss: 0.5919 - val_accuracy: 0.9500
# Epoch 34/40
# 4/4 [==============================] - 0s 8ms/step - loss: 0.4873 - accuracy: 0.9444 - val_loss: 0.2541 - val_accuracy: 0.9250
# Epoch 35/40
# 4/4 [==============================] - 0s 9ms/step - loss: 0.4842 - accuracy: 0.9389 - val_loss: 0.1542 - val_accuracy: 0.9500
# Epoch 36/40
# 4/4 [==============================] - 0s 9ms/step - loss: 0.4828 - accuracy: 0.9417 - val_loss: 0.1302 - val_accuracy: 0.9500
# Epoch 37/40
# 4/4 [==============================] - 0s 9ms/step - loss: 0.4811 - accuracy: 0.9417 - val_loss: 0.1166 - val_accuracy: 0.9750
# Epoch 38/40
# 4/4 [==============================] - 0s 8ms/step - loss: 0.4787 - accuracy: 0.9417 - val_loss: 0.1108 - val_accuracy: 0.9750
# Epoch 39/40
# 4/4 [==============================] - 0s 8ms/step - loss: 0.4761 - accuracy: 0.9417 - val_loss: 0.1076 - val_accuracy: 0.9750
# Epoch 40/40
# 4/4 [==============================] - 0s 8ms/step - loss: 0.4731 - accuracy: 0.9417 - val_loss: 0.1054 - val_accuracy: 0.9750

# %%
test_loss, test_acc = model.evaluate(X_test, y_test_ohe, verbose=False)

print( 'Test accuracy:', test_acc, " test_loss: ", test_loss)
# Out:
# Test accuracy: 0.9750000238418579  test_loss:  0.10542025417089462

# %% [markdown]
# ## <span style="color:orange">Student Challenge </span>:
# - In this particular dataset, it is better to perform train-test split according to the actors, that its to say:
#     - Three actors for training
#     - The other actor for test.
# Built a function that receive a list with three actors for training and the actor for test and return the respectives $( \mathbf{X_{tr}}, \mathbf{X_{te}}, \mathbf{y_{tr}}, \mathbf{y_{te}} )$

# %%
DATA_DIR = '../data/fsdd/'
def fun_ByActor(list_train = ['jackson','theo','yweweler'], pad_size=1000):

    
    
            
                
    return np.vstack(X_tr),np.vstack(X_te), np.array(y_tr),np.array(y_te)

# %%
X_tr, X_te, y_tr, y_te = fun_ByActor(['jackson','theo','yweweler'], 1000)

# %%
print X_tr.shape, X_te.shape, y_tr.shape, y_te.shape

# %% [markdown]
# Check the previous configuration.
#  - What about the performance?

# %%
model = keras.models.Sequential([

    
    
    
    
])
model.summary()

# %%
model.compile(optimizer=tf.train.AdamOptimizer(), 
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
history = model.fit(X_tr,
          y_tr,
          epochs=10,
          batch_size=1000,
          validation_data=(X_te, y_te))

plt.plot(history.history['acc'], label='Train Accuracy')
plt.plot(history.history['val_acc'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# %%
test_loss, test_acc = model.evaluate(X_te, y_te, verbose=False)

print 'Test accuracy:', test_acc, " test_loss: ", test_loss

# %% [markdown]
# ---
# <img src="https://gitlab.com/bivl2ab/academico/cursos-uis/ai/ai-uis-student/raw/master/imgs/bannerThanks.jpg" style="width:1000px;">
