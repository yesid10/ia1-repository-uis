# %% [markdown]
# <img src="https://gitlab.com/bivl2ab/academico/cursos-uis/ai/ai-uis-student/raw/master/imgs/banner_IA.png"  width="1000px" height="200px">
#
#
#
# # Welcome Back
#
# - Use collaboratory or jupyterNotebook desktop version
# - Load Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
pd.__version__
# Out:
# '0.24.2'

# %% [markdown]
# ## <span style="color:green"> If you are in colaboratoy </span>:

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd drive/My Drive/ai-uis-student/complement_notes
# !pwd

# %% [markdown]
# ## <span style="color:red"> Numpy </span>:

# %% [markdown]
# ---
#
# ### Ejercicio 1  <a name="eje1"></a>
#
# Las combinaciones lineales son una de las operaciones matemáticas mas importantes en aprendizaje de máquina e inteligencia artificial. Por ejemplo, el modelo de un neurona (principio de los metodos mas famosos de clasificación) puede modelarse como una combinación lineal de unas entradas que se múltiplican por unos pesos y se les suma un *bias*.
#
# <img src="https://gitlab.com/bivl2ab/academico/cursos-uis/ai/ai-uis-student/raw/master/imgs/dl1.jpg"  width="300px" height="200px">
#
# Esta representación gráfica se puede representar como $$y = \sum_{i=1}^{3}{ x_i \dot w_i } +b = XW^\top$$.
# Implemente una función que calcule la combinación lineal de un vector $\mathbf{X}$, unos pesos $\mathbf{W}$ y un sesgo (*bias*) $b$

# %%
def fun_eje_1_17(X, W, b):
    import numpy as np
    
    y = None
    
    return y

# %%
X = np.array([3,2,8] )
W = np.array([0.1, 0.3, 0.6])
b=33
fun_eje_1_17(X, W, b)

# %% [markdown]
# Escriba una función que reciba un numpy array y calcule las siguientes medidas utilizando las funciones de numpy correspondiente, dado un vector numpy de entrada.
# -  Mean $$\mu  = \frac{1}{n} \sum_{i=1}^{n} x^{(i)}$$
# - Mediana: cuando el total de datos $n$ es impar, la mediana es $(\frac{n+1}{2})^{th}$ término. Cuando $n$ es par, es $\frac{(\frac{n}{2})^{th}+(\frac{n+1}{2})^{th}}{2}$
# - El elemento con mayor frecuencia en el arreglo.
#
# Donde $x^{(i)}$ representa cada número del conjunto de datos.

# %%
def fun_eje_1_1(x):
    import numpy as np

# %%
x = np.array([1,2,3,1,2,1,1,1,3,2,2,1])
fun_eje_1_1(x)
# Out:
# (1.6666666666666667, 1.5, 1)

# %% [markdown]
# ### Ejercicio 2  <a name="eje2"></a>
#
# Dados dos arreglos correspondiente a información de los estudiantes: `s_bird` y `s_grade`. Retorne los arreglos ordenados utilizando como primer criterio la nota (*grade*), y segundo criterio la fecha de nacimiento (*bird*)

# %%
def fun_eje_1_2(s_bird, s_grade):
    
    
    return ss_bird, ss_grade

# %% [markdown]
# salida esperada

# %%
s_id = np.array([1980, 1983, 1990, 1995, 1995, 1997, 2000])
s_bird =  np.array([1.0, 4.2, 2.5, 4.1, 3.8, 4.1, 4.2])
fun_eje_1_2(s_id, s_bird )
# Out:
# (array([1980., 1990., 1995., 1995., 1997., 1983., 2000.]),
#  array([1. , 2.5, 3.8, 4.1, 4.1, 4.2, 4.2]))

# %% [markdown]
# ## <span style="color:red"> Pandas </span>:

# %% [markdown]
# ---
# ## Comportamiento del producto interno Bruto a nivel Mundial
#
# En los siguientes puntos vamos a explorar un dataset que describe el  crecimiento de la población mundial (`pop`) por país (`country`), y además describe el comportamiento del producto interno bruto (`gdpPercap`) y la experanza de vida (`lifeExp`).

# %%
import pandas as pd

data = pd.read_csv('../talleres/misc/FiveYearData.csv')

data.head()
# Out:
#        country  year         pop continent  lifeExp   gdpPercap
# 0  Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1  Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2  Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3  Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4  Afghanistan  1972  13079460.0      Asia   36.088  739.981106

# %% [markdown]
# #### Realice una grafica de tipo scatter que pinte en el eje x la población y en el eje y el gdpPercap

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
# country      1704 non-null object
# year         1704 non-null int64
# pop          1704 non-null float64
# continent    1704 non-null object
# lifeExp      1704 non-null float64
# gdpPercap    1704 non-null float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 80.0+ KB

# %%
data.plot(kind="scatter", x = "pop", y="gdpPercap" )
#data.plot.pie( x = "pop", y="gdpPercap")

# %% [markdown]
# #### Realice una grafica de tipo acatter que pinte en el eje x el año, en el eje y la variable "lifeExp" y como tamaño "gdpPercap".

# %%
data.plot(kind="scatter", x="year", y="lifeExp", alpha=0.2, s=data["gdpPercap"]/1000)

# %% [markdown]
# ahora realice la misma gráfica pero utilice los continentes como paleta de colores para obtener mas información.

# %%
a = data.continent.factorize()
a
# Out:
# (array([0, 0, 0, ..., 2, 2, 2]),
#  Index(['Asia', 'Europe', 'Africa', 'Americas', 'Oceania'], dtype='object'))

# %% [markdown]
# Grafique la correlación temporal entre **lifeExp** y el **gdpPercap** utilizando una ventana temporal de 50 valores.

# %%
data.plot(kind="scatter", x="year", y="lifeExp", alpha=0.2, c = a[0], cmap=plt.get_cmap("jet"),  s=data["gdpPercap"]/1000)

# %%
data.plot(kind="scatter", x="lifeExp", y="gdpPercap", alpha=0.1)

# %%
data.corr()
# Out:
#                year       pop   lifeExp  gdpPercap
# year       1.000000  0.082308  0.435611   0.227318
# pop        0.082308  1.000000  0.064955  -0.025600
# lifeExp    0.435611  0.064955  1.000000   0.583706
# gdpPercap  0.227318 -0.025600  0.583706   1.000000

# %%
data.lifeExp.rolling(window=500).corr(other=data.gdpPercap).plot()

# %%
plt.figure(figsize=(10,3))
plt.subplot(121)
sample = np.random.normal(loc=4, scale=.5, size=10000)
print (type(sample))
print (sample.shape)
plt.hist(sample, bins=30);
plt.subplot(122)
sample = np.random.random(size=10000)
plt.hist(sample, bins=30);
# Out:
# <class 'numpy.ndarray'>
# (10000,)

# %% [markdown]
# ## <span style="color:red"> Statistical Distributionss </span>:

# %% [markdown]
# ### Ejercicio 3 <a name="eje5"></a>
#
# Considere el dataset `../data/gapminder-FiveYearData.csv`. Queremos modelar la distribución de los datos la caracteristica: **"producto interno bruto"** (`gdpPercap`). Sin embargo no sabemos la forma de la distribución. Por lo tanto vamos a utilizar el teorema del límite central, para aproximar estos datos a la distribución normal: $\mathcal{N} \left ( \mu(X), \frac{\sigma(X)}{\sqrt{N}} \right )$.
#
# Contruya una función que:
#
# 1. Calcule los promedios tomando $N = {10,20,40}$ muestras (realice 1000 iteraciones para cada $N$).
#     - Cada conjunto de muestran son seleccionadas de forma aleatoria del conjunto de datos.
# 2. Grafique un subplot con la forma de cada aproximación para los tres tamaños de muestra.
# 3. Devuelva la lista de los parametros de $\mathcal{N} \left ( \mu(X), \frac{\sigma(X)}{\sqrt{N}} \right )$(para cada N sobre las 1000 iteraciones)

# %%
def dinter14():
    import pandas as pd
    import numpy as np
    import matplotlib.pyplot as plt
    
  
    #code here
  
    return list_mu, list_std

# %%
list_mu, list_std = dinter14()
print(list_mu)
print(list_std)
# Out:
# [7178.43560695395, 7211.341088109595, 7228.941013117373]
# [969.0980197355541, 484.5548281306127, 245.24513480075353]

# %% [markdown]
# ---
# <img src="https://gitlab.com/bivl2ab/academico/cursos-uis/ai/ai-uis-student/raw/master/imgs/bannerThanks.jpg" alt="Drawing" style="width:700px;">
