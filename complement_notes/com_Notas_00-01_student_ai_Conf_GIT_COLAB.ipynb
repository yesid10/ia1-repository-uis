# %% [markdown]
# <img src="https://gitlab.com/bivl2ab/academico/cursos-uis/ai/ai-uis-student/-/raw/master/imgs/img_IA.jpg" style="width:1500px;heigth:100px">
#
# # Connecting GITLAB with COLAB

# %%
 #@title 1. MONTAR EL DRIVE { display-mode: "form" }
from google.colab import drive
drive.mount('/content/drive/', force_remount=True)
# %cd drive/My Drive/
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/
# /content/drive/My Drive

# %%
#@title 2. Cree o localice la course-I.A { display-mode: "form" }
import os
path_ria = '/content/drive/My Drive/'
os.mkdir(os.path.join(path_ria, 'course-IA1')) if 'course-IA1' not in os.listdir(path_ria) else os.chdir(os.path.join(path_ria, 'course-IA1'))
print(os.getcwd())
# Out:
# /content/drive/My Drive

# %%
#@title 3. Clone (clone) o actualice (pull) el course-I.A2 { display-mode: "form" }
path_ria = '/content/drive/My Drive/course-IA1'
os.chdir(path_ria)
print(os.getcwd())

if 'ai-uis-student' in os.listdir('.'):
  print("pull repo is required") 
  os.chdir(os.path.join(os.getcwd(), 'ai-uis-student'))
  ! git reset --hard HEAD
  ! git clean -f -d
  ! git pull --progress origin master

else:
  print("clone repo is required") 
  # !git clone "https://gitlab.com/bivl2ab/academico/cursos-uis/ai/ai-uis-student"
  os.chdir(os.path.join(os.getcwd(), 'ai-uis-student'))
  
print(os.getcwd())
# Out:
# /content/drive/My Drive/course-IA1
# clone repo is required
# Cloning into 'ai-uis-student'...
# ...
# remote: Enumerating objects: 2884, done.
# remote: Counting objects: 100% (2884/2884), done.
# remote: Compressing objects: 100% (2505/2505), done.
# remote: Total 2884 (delta 422), reused 2827 (delta 371), pack-reused 0
# Receiving objects: 100% (2884/2884), 270.59 MiB | 18.22 MiB/s, done.
# Resolving deltas: 100% (422/422), done.
# Checking out files: 100% (2280/2280), done.
# /content/drive/My Drive/course-IA1/ai-uis-student

# %%
os.listdir('.')
# Out:
# ['.git',
#  '.gitignore',
#  'README.md',
#  'bib',
#  'code',
#  'complement_notes',
#  'data',
#  'imgs',
#  'notebooks',
#  'presentations',
#  'projects',
#  'talleres20192']

# %% [markdown]
# <img src="https://gitlab.com/bivl2ab/academico/cursos-uis/cv/cv-uis-student/raw/master/imgs/bannerThanks.jpg" style="width:1000px;">
