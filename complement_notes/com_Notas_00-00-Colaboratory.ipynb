# %% [markdown]
#  <img src="https://gitlab.com/bivl2ab/academico/cursos-uis/ai/ai-uis-professor/raw/master/imgs/img_IA.jpg" alt="Drawing" style="width:700px;">
#
# # <center> 01. Intro to Colaboratory with Gitlab! </center>
#
# Colaboratory es un entorno de notebook de Jupyter gratuito que no requiere configuración y se ejecuta completamente en la nube. Con Colaboratory, puedes escribir y ejecutar código, guardar y compartir análisis, y acceder a recursos informáticos potentes, todo gratis en tu navegador.

# %% [markdown]
# # GITLAB and COLAB
#
# Primero vamos a ejecutar las siguientes lineas para `clonar` el repositorio del curso en nuestro drive. Recuerda que tienes este notebook o ejecutas la siguiente celda desde colaboratory

# %% [markdown]
# ### Clonar
# El proceso de clonar solo se realiza una vez. El descarga el archivo desde **Gitlab** y deja el la carpeta lista para ser sincronizada

# %%
from google.colab import drive
drive.mount('/content/drive')
# !cd /content/drive/My\ Drive/ && git clone https://gitlab.com/bivl2ab/academico/cursos-uis/ai/ai-uis-student.git

# %% [markdown]
# ## Actualizamos el curso: PULL
#
# Esto se ejecuta en cada clase, para actualizar la última versión del curso. Esta celda deberá realizarce cada vez que llegamos al curso.

# %%
from google.colab import drive
drive.mount('/content/drive')
# !cd /content/drive/My\ Drive/ai-uis-student && git pull origin master

# %% [markdown]
# Otra forma para localizar el archivo

# %%
# %cd drive/My Drive/ai-uis-student

# %%
! git pull origin master

# %% [markdown]
# Si hemos hecho cambios en el repositorio, tal vez no nos deje sincronizar tan facil. Entonces podemos **forzar** a que se sobre-escriban los archivos en la carpeta local. Para ello ejecutamos el siguiente código

# %%
# %cd drive/My Drive/cv-uis-student
! git reset --hard HEAD
! git clean -f -d
! git pull --progress origin master

# %% [markdown]
# ## Una manera de visualizar y ejecutar  notebooks
#
# El documento que lees es un <a href="https://jupyter.org/">notebook de Jupyter</a> alojado en Colaboratory. No es una página estática, sino un entorno interactivo que te permite escribir y ejecutar código en Python y en otros lenguajes.
#
# Por ejemplo, esta es una <strong>celda de código</strong> con una secuencia de comandos Python corta que calcula un valor, lo almacena en una variable y devuelve el resultado:

# %%
seconds_in_a_day = 24 * 60 * 60
seconds_in_a_day
# Out:
# 86400

# %%
seconds_in_a_week = 7 * seconds_in_a_day
seconds_in_a_week
# Out:
# 604800

# %% [markdown]
# ## Celdas de texto
# Esto es una **celda de texto**. Usted puede hacer **doble-click** para editar esta celda. Las celdas de texto usan la sintáxis de Markdown, para aprender más mirar [Guia de Markdown de Colaboratory](/notebooks/markdown_guide.ipynb).
#
# Usted también puede incluir fórmulas matemáticas en las celdas de texto usando [LaTeX](http://www.latex-project.org/) la cual es renderizada gracias a [MathJax](https://www.mathjax.org).
# Solo es necesario colocar la definición en un par de símbolos **\$**. Por ejemplo: `$\sqrt{3x-1}+(1+x)^2$` se convierte en:
# $\sqrt{3x-1}+(1+x)^2.$

# %% [markdown]
# ## Instalar librerías que no están en colaboratory
#
# Para importar librerías que no están en Colaboratory por defecto, usted puede usar `!pip install` o `!apt-get install`.

# %%
# !pip install -q matplotlib-venn

# %%
# !apt-get -qq install -y libfluidsynth1

# %%
# https://pypi.python.org/pypi/pydot
# !apt-get -qq install -y graphviz && pip install -q pydot
import pydot

# %%
# Para versiones específicas:
# !pip install tensorflow==1.2

# %%
# Para actualizar la versión actual de la librería: 
# !pip install --upgrade tensorflow

# %% [markdown]
# ## Cómo cargar datos desde sistemas externos
# ### Subir archivos desde el sistema de archivos local
#
# <code>files.upload</code> muestra un diccionario de los archivos que se cargaron.
# El diccionario está codificado según el nombre de archivo y los valores son los datos que se subieron.

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-c8946bec-bb86-4811-abc1-5e803d67597d" name="files[]" multiple disabled />
#      <output id="result-c8946bec-bb86-4811-abc1-5e803d67597d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %% [markdown]
# ---
# ## Activar Google Drive en el Colab
#
# El ejemplo siguiente muestra cómo activar Google Drive en el entorno de ejecución mediante un código de autorización y cómo escribir y leer archivos allí.
#
# Ten en cuenta que solo se puede leer, escribir o mover archivos.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# ---
# ## Usa aceleración de hardware
# ### Colab with GPU o TPU
#
# Google colab tiene a disposición tarjetas [GPU](https://cloud.google.com/gpu) para acelerar los procesos a ejecutar en el notebook. Incrementando a gran escala el rendimiento obtenido usando simples unidades CPU.
#
# ### Habilitando unidades GPU o TPU
#
# Primero que todo, usted necesitará habilitar las GPUs o TPUs para el notebook:
#
# - Navegar hasta **Editar**→**Configuración del Block de notas**
# - Seleccionar **GPU** o **TPU** del menú desplegable de _Aceleración de Hardware_

# %% [markdown]
# ## Referencias
#
# [1] Colab doc. La principal información de este notebook proviene de aquí

# %% [markdown]
#  <img src="https://gitlab.com/bivl2ab/academico/cursos-uis/ai/ai-uis-professor/raw/master/imgs/bannerThanks.jpg" alt="Drawing" style="width:700px;">
