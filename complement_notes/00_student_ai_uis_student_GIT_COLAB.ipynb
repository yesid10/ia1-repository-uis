# %% [markdown]
# <img src="https://gitlab.com/bivl2ab/academico/cursos-uis/ai/ai-uis-student/raw/master/imgs/banner_IA.png"  width="1000px" height="200px">
#
# # Connecting GITLAB with COLAB

# %%
 #@title **1. MONTAR EL DRIVE** { display-mode: "form" }
from google.colab import drive
drive.mount('/content/drive/', force_remount=True)
# %cd drive/My Drive/
# Out:
# Mounted at /content/drive/
# /content/drive/My Drive

# %%
#@title **2. student: path course** { display-mode: "form" }
import os
#@markdown completela información donde quiere que quede su curso. Por ejemplo:

#@markdown ```'/content/drive/My Drive/course-IA1'```

path_ria = "/content/drive/My Drive/...." #@param {type:"string"}
os.chdir(path_ria)
print(os.getcwd())
print(os.listdir('.'))
# Out:
# /content/drive/My Drive/main/academic/courses/2018-UIS-AritfitialInteligence
# ['general_course', 'student_ai_Conf_GIT-COLAB.ipynb', 'Untitled0.ipynb', 'ai-uis-professor', 'ai-uis-student', 'professor_ai-uis-professor_GIT-COLAB.ipynb', 'professor_ai-uis-student_GIT-COLAB.ipynb']

# %%
#@title **3. student Clone (clone) o actualice (pull) student** { display-mode: "form" }
import os
import urllib.parse
from getpass import getpass

print(os.getcwd())

if 'ai-uis-student' in os.listdir(path_ria):
  print("pull repo student is required") 
  os.chdir(os.path.join(path_ria , 'ai-uis-student'))
  #!git add . 
  #!git commit -m "from repo or"
  ! git reset --hard HEAD
  ! git clean -f -d
  ! git pull --progress origin master

else:
  print("clone repo is required") 
  # !git clone "https://$USER:$PASS@gitlab.com/bivl2ab/academico/cursos-uis/ai/ai-uis-student"
  os.chdir(os.path.join(os.getcwd(), 'ai-uis-student'))

print(os.getcwd())

# %% [markdown]
# <img src="https://gitlab.com/bivl2ab/academico/cursos-uis/cv/cv-uis-student/raw/master/imgs/bannerThanks.jpg" style="width:1000px;">
