# %% [markdown]
# <img src="https://gitlab.com/bivl2ab/academico/cursos-uis/ai/ai-uis-student/raw/master/imgs/banner_IA.png"  width="1000px" height="250px">

# %%
#@title Imports
import os
import gc
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %%
#@title Descargar el dataset
# !gdown https://drive.google.com/uc?id=1V-axj71FKJHWIbZnYUuJz-FbOJLVTKDu
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1V-axj71FKJHWIbZnYUuJz-FbOJLVTKDu
# To: /content/Reporte_Hurto_por_Modalidades_Polic_a_Nacional.csv
# 100% 55.5M/55.5M [00:00<00:00, 147MB/s]

# %% [markdown]
# ### **RETO DE ANALÍTICA DE DATOS. REPORTE DE HURTOS**
#
# Como líder del departamento de análisis de datos de un municipio en Colombia, usted debe explicar cómo es el comportamiento de los hurtos del municipio en el que reside con respecto a otros municipios del departamento y así mismo, con respecto al comportamiento del país.
#
# De igual forma, es necesario analizar la cantidad de hurtos realizados en un municipio, así como también los medios con los que realizan estos hurtos y quién los realiza. Para ello, utilice el [dataset](https://www.datos.gov.co/Seguridad-y-Defensa/Reporte-Hurto-por-Modalidades-Polic-a-Nacional/6sqw-8cg5/data) el cual puede descargar aquí: [Reporte de hurtos por modalidades](https://drive.google.com/uc?id=1V-axj71FKJHWIbZnYUuJz-FbOJLVTKDu) realizado por la policía nacional. El cual contiene variables tales como el departamento, municipio, el código DANE, los medios por los cuales se realizó el robo (tipos de armas), la fecha del hecho, el género, el grupo etario, el tipo de hurto, y la cantidad.
#
# Por lo cual, debe concluir con una política para disminuir los índices de hurtos, según en análisis de datos observado. Para ello:

# %%
reporte_hurto = pd.read_csv('/content/Reporte_Hurto_por_Modalidades_Polic_a_Nacional.csv', delimiter=',')
data_rows, data_cols = reporte_hurto.shape
print(f'There are {data_rows} rows and {data_cols} columns')
reporte_hurto.head(10)
# Out:
# There are 536674 rows and 9 columns
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (2) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    DEPARTAMENTO               MUNICIPIO CODIGO DANE  \
# 0       CAQUETÁ  SAN VICENTE DEL CAGUÁN    18753000
# 1         CAUCA            POPAYÁN (CT)    19001000
# 2         HUILA                PITALITO    41551000
# 3         VALLE                 JAMUNDÍ    76364000
# 4      AMAZONAS            LETICIA (CT)    91001000
# 5        BOYACÁ                   TASCO    15790000
# 6      CASANARE              YOPAL (CT)    85001000
# 7      CASANARE              YOPAL (CT)    85001000
# 8  CUNDINAMARCA        BOGOTÁ D.C. (CT)    11001000
# 9  CUNDINAMARCA        BOGOTÁ D.C. (CT)    11001000
#
#                   ARMAS MEDIOS FECHA HECHO     GENERO GRUPO ETARIO  \
# ...

# %% [markdown]
# 1. Seleccione una Municipio que contenga almenos 1000 registros. Este municipio será su base de análisis y no se pueden repetir municipios entre estudiantes [1 punto].

# %%
#@title **Respuesta del estudiante**
"""

Coloque su código acá

"""
# Out:
# '\n\nColoque su código acá\n\n'

# %% [markdown]
# 2. Grafique la matrix de correlación entre las variables (armas medios, genero, grupo etareo y tipo de hurto) del dataset para su municipio, así como una tendencia temporal del número de hurtos desde 2010 hasta 2022, según disponibilidad. (Concluya). [1 punto]

# %%
#@title **Respuesta del estudiante**
"""

Coloque su código acá

"""
# Out:
# '\n\nColoque su código acá\n\n'

# %% [markdown]
# 3. Grafique la matrix de correlación entre las variables (armas medios, genero, grupo etareo y tipo de hurto) del dataset para Colombia, así como una tendencia temporal del número de hurtos desde 2010 hasta 2022. Compare con el de su ciudad y  Concluya. **[1 punto]**

# %%
#@title **Respuesta del estudiante**
"""

Coloque su código acá

"""
# Out:
# '\n\nColoque su código acá\n\n'

# %% [markdown]
# 4. Grafique tres diagramas de barras mostrando la distribución de hurtos según las armas, el genero y el grupo Etario, respectivamente. Este análisis realícelo para su ciudad. **[1 punto]**

# %%
#@title **Respuesta del estudiante**
"""

Coloque su código acá

"""
# Out:
# '\n\nColoque su código acá\n\n'

# %% [markdown]
# 5. Calcule el número de hurtos por cada semana según el arma.  Grafique un histograma y un violinplot con esta información, según cada arma [1 punto]

# %%
#@title **Respuesta del estudiante**
"""

Coloque su código acá

"""
# Out:
# '\n\nColoque su código acá\n\n'

# %% [markdown]
# ##**RECUERDA QUE LOS MAS IMPORTANTE SON LAS CONCLUSIONES QUE PUEDAS GENERAR AL RESPECTO!!!**
#
#
# ## Enviar el correo
#
# Añade tu código como prefijo en el nombre del notebook y sigue los siguientes pasos: `Archivo (File) > Descargar (Download) > Descargar .ipynb (Download .ipynb)`. Luego de esto, tendrás tu notebook listo para adjuntarlo como correo electrónico a los profesores que les corresponda:
#
# *   Fabio Martínez, famarcar@saber.uis.edu.co
# *    Gustavo Garzón gustavo.garzon@saber.uis.edu.co
#
#  ¡Muchos exitos!
#
# **IMPORTANTE:** El asunto del correo es 'Parcial 1 - IA1 - XXXXX', donde XXXXX corresponde al código del alumno.
